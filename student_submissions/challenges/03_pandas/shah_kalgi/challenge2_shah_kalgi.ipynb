# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

movies = pd.read_csv('2013_movies.csv')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
# Title                 100 non-null object
# Budget                89 non-null float64
# DomesticTotalGross    100 non-null int64
# Director              96 non-null object
# Rating                100 non-null object
# Runtime               100 non-null int64
# ReleaseDate           100 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 5.5+ KB

# %%
movies = movies.fillna(0)
movies.head(10)
# Out:
#                                  Title       Budget  DomesticTotalGross  \
# 0      The Hunger Games: Catching Fire  130000000.0           424668047
# 1                           Iron Man 3  200000000.0           409013994
# 2                               Frozen  150000000.0           400738009
# 3                      Despicable Me 2   76000000.0           368061265
# 4                         Man of Steel  225000000.0           291045518
# 5                              Gravity  100000000.0           274092705
# 6                  Monsters University          0.0           268492764
# 7  The Hobbit: The Desolation of Smaug          0.0           258366855
# 8                     Fast & Furious 6  160000000.0           238679850
# 9            Oz The Great and Powerful  215000000.0           234911825
#
#                     Director Rating  Runtime          ReleaseDate
# 0           Francis Lawrence  PG-13      146  2013-11-22 00:00:00
# ...

# %%
X=movies['Runtime']

y=movies['DomesticTotalGross']

# %%
sns.pairplot(movies, kind="reg")

# %%
plt.scatter(movies['DomesticTotalGross'], movies['Runtime'], alpha=.7)

# %%
plt.scatter(movies['Runtime'], movies['DomesticTotalGross'], alpha=.7)

# %%
movies.groupby(['Rating'])['Runtime', 'DomesticTotalGross'].mean()
# Out:
#            Runtime  DomesticTotalGross
# Rating
# G       107.000000        2.684928e+08
# PG       99.933333        1.311357e+08
# PG-13   117.510638        1.114498e+08
# R       110.729730        6.989243e+07

# %%
movies['ReleaseDate'] = pd.to_datetime(movies['ReleaseDate'])
movies.head(10)
# Out:
#                                  Title       Budget  DomesticTotalGross  \
# 0      The Hunger Games: Catching Fire  130000000.0           424668047
# 1                           Iron Man 3  200000000.0           409013994
# 2                               Frozen  150000000.0           400738009
# 3                      Despicable Me 2   76000000.0           368061265
# 4                         Man of Steel  225000000.0           291045518
# 5                              Gravity  100000000.0           274092705
# 6                  Monsters University          0.0           268492764
# 7  The Hobbit: The Desolation of Smaug          0.0           258366855
# 8                     Fast & Furious 6  160000000.0           238679850
# 9            Oz The Great and Powerful  215000000.0           234911825
#
#                     Director Rating  Runtime ReleaseDate
# 0           Francis Lawrence  PG-13      146  2013-11-22
# 1                Shane Black  PG-13      129  2013-05-03
# ...

# %%
sns.factorplot(data=movies, x='ReleaseDate', y='DomesticTotalGross', col='Rating')

# %%
g=sns.FacetGrid(movies, col='Rating')
g.map(plt.scatter, 'ReleaseDate', 'DomesticTotalGross')

# %%
movies_filtered = movies.loc[(movies != 0).all(axis=1), :]

# %%
movies_filtered.groupby(['Director'])['DomesticTotalGross'].max()
movies_filteres['Director'].max()
# Out:
# 'Zack Snyder'

# %%
movies['Month'] = movies['ReleaseDate'].dt.strftime('%B-%Y')
movies.head(10)
# Out:
#                                  Title       Budget  DomesticTotalGross  \
# 0      The Hunger Games: Catching Fire  130000000.0           424668047
# 1                           Iron Man 3  200000000.0           409013994
# 2                               Frozen  150000000.0           400738009
# 3                      Despicable Me 2   76000000.0           368061265
# 4                         Man of Steel  225000000.0           291045518
# 5                              Gravity  100000000.0           274092705
# 6                  Monsters University          0.0           268492764
# 7  The Hobbit: The Desolation of Smaug          0.0           258366855
# 8                     Fast & Furious 6  160000000.0           238679850
# 9            Oz The Great and Powerful  215000000.0           234911825
#
#                     Director Rating  Runtime ReleaseDate          Month
# 0           Francis Lawrence  PG-13      146  2013-11-22  November-2013
# ...

# %%
sns.axes_style('white')
sns.set_style('white')
colors = ['lightblue']
sns.barplot("Month", "DomesticTotalGross", data=movies, palette=colors).set_title('Mean Domestic Total Gross by Month in 2013')
