# %% [markdown]
# **Topic:**        Challenge Set 9
# **Subject:**      SQL
# **Date:**         10/18/2017
# **Name:**         Laura Howard

# %% [markdown]
# ### Part i

# %% [markdown]
# **1) Which customers are from the UK?**
# > Answers:
# Around the Horn
# B's Beverages
# Consolidated Holdings
# Eastern Connection
# Island Trading
# North/South
# Seven Seas Imports
#
# ```sql
# SELECT *
# FROM Customers
# WHERE Country = 'UK'
# ```

# %% [markdown]
# **2) What is the name of the customer who has the most orders?**
# > Answer = Ernst Handel
#
# ```sql
# SELECT CustomerName, COUNT(*) AS OrderCount
# FROM Customers
# JOIN Orders ON Customers.CustomerID = Orders.CustomerID
# GROUP BY Customers.CustomerID
# ORDER BY OrderCount DESC LIMIT 1;
# ```

# %% [markdown]
# **3) Which supplier has the highest average product price?**
# >Answer = Aux joyeux ecclésiastiques
#
# ```sql
# SELECT SupplierName, AVG(Price) AS AverageProductPrice
# FROM Suppliers
# JOIN Products ON Suppliers.SupplierID = Products.SupplierID
# GROUP BY Suppliers.SupplierID
# ORDER BY AverageProductPrice DESC LIMIT 1;
# ```

# %% [markdown]
# **4) How many different countries are all the customers from?**
# > Answer = 21
#
# ```sql
# SELECT COUNT (DISTINCT Country)
# FROM Customers
# ```

# %% [markdown]
# 5) What category appears in the most orders?
# > Answer = Dairy Products
#
# ```sql
# SELECT CategoryName, COUNT(*) AS OrderCount
# FROM OrderDetails
# JOIN Products ON OrderDetails.ProductID = Products.ProductID
# JOIN Categories ON Products.CategoryID = Categories.CategoryID
# GROUP BY Categories.CategoryID
# ORDER BY OrderCount DESC LIMIT 1;
# ```

# %% [markdown]
# 6) What was the total cost for each order?
# ```sql
# SELECT OrderID, SUM(Price) * Quantity AS TotalCost
# FROM OrderDetails
# JOIN Products ON Products.ProductID = OrderDetails.ProductID
# GROUP BY OrderDetails.OrderID
# ORDER BY TotalCost DESC;
# ```

# %% [markdown]
# 7) Which employee made the most sales (by total price
# > Answer = Margaret Peacock
#
# ```sql
# SELECT FirstName, LastName, SUM(TotalCost) AS AllSales FROM Orders
# JOIN Employees ON Orders.EmployeeID = Employees.EmployeeID
# JOIN
#   (
#   SELECT OrderID, SUM(Price) * Quantity AS TotalCost
#   FROM OrderDetails
#   JOIN Products ON Products.ProductID = OrderDetails.ProductID
#   GROUP BY OrderDetails.OrderID
#   ORDER BY TotalCost DESC
#   ) CostPerOrder
# ON CostPerOrder.OrderID = Orders.OrderID
# GROUP BY Employees.EmployeeID
# ORDER BY AllSales DESC LIMIT 1;
# ```

# %% [markdown]
# 8) Which employees have BS degrees?
# > Answer = Janet Leverling and Steven Buchanan
#
# ```sql
# SELECT *
# FROM [Employees]
# WHERE Notes LIKE '%BS%';
# ```

# %% [markdown]
# 9) Which supplier of three or more products has the highest average product price?
# > Answer = Tokyo Traders
#
# ```sql
# SELECT SupplierName, AVG(Price) AS AverageProductPrice, COUNT(*) AS ProductCount
# FROM Products
# JOIN Suppliers ON Products.SupplierID = Suppliers.SupplierID
# GROUP BY Products.SupplierID
# HAVING ProductCount >= 3
# ORDER BY AverageProductPrice DESC LIMIT 1;
# ```

# %% [markdown]
# ### Part ii

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

cnx = create_engine('postgresql://postgres@54.183.254.126:5432')
#cnx = create_engine('postgresql://username:password@ip_address:port/dbname')
#port ~ 5432

# %%
Salries = pd.read_sql_query('''SELECT * FROM Salaries''',cnx)

# %%
Salries.head()
# Out:
#    yearid teamid lgid   playerid     salary
# 0    1985    BAL   AL  murraed02  1472819.0
# 1    1985    BAL   AL   lynnfr01  1090000.0
# 2    1985    BAL   AL  ripkeca01   800000.0
# 3    1985    BAL   AL   lacyle01   725000.0
# 4    1985    BAL   AL  flanami01   641667.0

# %%
AllstarFull = pd.read_sql_query('''SELECT * FROM AllstarFull''',cnx)

# %%
AllstarFull.head()
# Out:
#     playerid  yearid gamenum        gameid teamid lgid gp startingpos
# 0  gomezle01    1933       0  ALS193307060    NYA   AL  1           1
# 1  ferreri01    1933       0  ALS193307060    BOS   AL  1           2
# 2  gehrilo01    1933       0  ALS193307060    NYA   AL  1           3
# 3  gehrich01    1933       0  ALS193307060    DET   AL  1           4
# 4  dykesji01    1933       0  ALS193307060    CHA   AL  1           5

# %%
Schools = pd.read_sql_query('''SELECT * FROM Schools''',cnx)

# %%
Schools.head()
# Out:
#      schoolid                       schoolname        schoolcity schoolstate  \
# 0  abilchrist     Abilene Christian University           Abilene          TX
# 1     adelphi               Adelphi University       Garden City          NY
# 2    adrianmi                   Adrian College            Adrian          MI
# 3    airforce  United States Air Force Academy  Colorado Springs          CO
# 4       akron              University of Akron             Akron          OH
#
#   schoolnick
# 0   Wildcats
# 1   Panthers
# 2   Bulldogs
# 3    Falcons
# 4       Zips

# %% [markdown]
# 1) What was the total spent on salaries by each team, each year?

# %%
pd.read_sql_query('''SELECT teamid, yearid, SUM(salary) FROM Salaries GROUP BY teamid, yearid ORDER by teamid, yearid''',cnx)
# Out:
#     teamid  yearid          sum
# 0      ANA    1997   31135472.0
# 1      ANA    1998   41281000.0
# 2      ANA    1999   55388166.0
# 3      ANA    2000   51464167.0
# 4      ANA    2001   47535167.0
# 5      ANA    2002   61721667.0
# 6      ANA    2003   79031667.0
# 7      ANA    2004  100534667.0
# 8      ARI    1998   32347000.0
# 9      ARI    1999   68703999.0
# 10     ARI    2000   81027833.0
# 11     ARI    2001   85082999.0
# 12     ARI    2002  102819999.0
# 13     ARI    2003   80657000.0
# 14     ARI    2004   69780750.0
# 15     ARI    2005   62329166.0
# 16     ARI    2006   59684226.0
# 17     ARI    2007   52067546.0
# 18     ARI    2008   66202712.0
# 19     ARI    2009   73115666.0
# 20     ARI    2010   60718166.0
# 21     ARI    2011   53639833.0
# 22     ARI    2012   73804833.0
# 23     ARI    2013   90132000.0
# 24     ATL    1985   14807000.0
# 25     ATL    1986   17102786.0
# 26     ATL    1987   16544560.0
# 27     ATL    1988   12728174.0
# ...

# %% [markdown]
# 2) What is the first and last year played for each player? *Hint:* Create a new table from 'Fielding.csv'.

# %%
# Created table in database in my AWS 

Fiedling = pd.read_sql_query('''SELECT * FROM Fielding''',cnx)
Fiedling.head()
# Out:
#     playerid  yearid  stint teamid lgid pos   g  gs  innouts     po    a  \
# 0  ansonca01    1871      1    RC1   NA  1B   1 NaN      NaN    7.0  0.0
# 1  biermch01    1871      1    FW1   NA  1B   1 NaN      NaN    9.0  0.0
# 2  carleji01    1871      1    CL1   NA  1B  29 NaN      NaN  295.0  4.0
# 3  connone01    1871      1    TRO   NA  1B   4 NaN      NaN   35.0  1.0
# 4  cravebi01    1871      1    TRO   NA  1B   2 NaN      NaN   18.0  1.0
#
#       e    dp  pb  wp  sb  cs  zr
# 0   0.0   0.0 NaN NaN NaN NaN NaN
# 1   2.0   0.0 NaN NaN NaN NaN NaN
# 2  34.0  10.0 NaN NaN NaN NaN NaN
# 3   5.0   1.0 NaN NaN NaN NaN NaN
# 4   1.0   1.0 NaN NaN NaN NaN NaN

# %%
pd.read_sql_query('''
    (SELECT DISTINCT(playerid), yearid FROM Fielding x
    WHERE yearid <= ALL
    (SELECT yearid FROM Fielding y
    WHERE y.playerid=x.playerid)
    ORDER BY playerid)

    UNION

    (SELECT DISTINCT(playerid), yearid FROM Fielding x
    WHERE yearid >= ALL
    (SELECT yearid FROM Fielding y
    WHERE y.playerid=x.playerid)
    ORDER BY playerid)
    ORDER BY playerid, yearid''',cnx).head(10)
# Out:
#     playerid  yearid
# 0  aardsda01    2004
# 1  aardsda01    2013
# 2  aaronha01    1954
# 3  aaronha01    1976
# 4  aaronto01    1962
# 5  aaronto01    1971
# 6   aasedo01    1977
# 7   aasedo01    1990
# 8   abadan01    2001
# 9   abadan01    2003

# %% [markdown]
# 3) Who has played the most all star games?

# %%
pd.read_sql_query('''SELECT playerid, COUNT(*) AS total_games_played FROM AllstarFull WHERE GP = '1' GROUP BY playerid ORDER BY total_games_played DESC LIMIT 1''',cnx)
# Out:
#     playerid  total_games_played
# 0  aaronha01                  24

# %% [markdown]
# 4) Which school has generated the most distinct players? *Hint:* Create new table from 'CollegePlaying.csv'.

# %%
# Created table in database in my AWS 
SchoolsPlayers = pd.read_sql_query('''SELECT * FROM SchoolsPlayers''',cnx)
SchoolsPlayers.head()
# Out:
#     playerid   schoolid  yearmin  yearmax
# 0  aardsda01     pennst     2001     2001
# 1  aardsda01       rice     2002     2003
# 2  abbeybe01    vermont     1888     1892
# 3  abbotgl01  carkansas     1970     1970
# 4  abbotje01   kentucky     1991     1992

# %%
pd.read_sql_query('''SELECT schoolid, COUNT(DISTINCT(playerid)) AS total_players FROM SchoolsPlayers GROUP BY schoolid ORDER BY total_players DESC LIMIT 1''',cnx)
# Out:
#   schoolid  total_players
# 0      usc            102

# %% [markdown]
# 5) Which players have the longest career? Assume that the `debut` and `finalGame` columns comprise the start and end, respectively, of a player's career. *Hint:* Create a new table from 'Master.csv'. Also note that strings can be converted to dates using the [`DATE`](https://wiki.postgresql.org/wiki/Working_with_Dates_and_Times_in_PostgreSQL#WORKING_with_DATETIME.2C_DATE.2C_and_INTERVAL_VALUES) function and can then be subtracted from each other yielding their difference in days.

# %%
Master = pd.read_sql_query('''SELECT * FROM Master''',cnx)
Master.head()
# Out:
#     playerid  birthyear  birthmonth  birthday birthcountry birthstate  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthcity  deathyear  deathmonth  deathday    ...     namelast  \
# 0      Denver        NaN         NaN       NaN    ...      Aardsma
# 1      Mobile        NaN         NaN       NaN    ...        Aaron
# 2      Mobile     1984.0         8.0      16.0    ...        Aaron
# 3      Orange        NaN         NaN       NaN    ...         Aase
# 4  Palm Beach        NaN         NaN       NaN    ...         Abad
#
#         namegiven weight height bats throws       debut   finalgame   retroid  \
# ...

# %%
pd.read_sql_query('''SELECT playerid, (finalgame - debut)/365 AS years_played FROM Master WHERE finalgame IS NOT NULL AND debut IS NOT NULL ORDER BY years_played DESC LIMIT 50''',cnx)
# Out:
#      playerid  years_played
# 0   altroni01            35
# 1   orourji01            32
# 2   minosmi01            31
# 3   olearch01            30
# 4   lathaar01            29
# 5   mcguide01            27
# 6   eversjo01            27
# 7    ryanno01            27
# 8   jennihu01            27
# 9   streega01            27
# 10  ansonca01            26
# 11  broutda01            25
# 12   johnto01            25
# 13  moyerja01            25
# 14  francju01            25
# 15  quinnja01            24
# 16  gleaski01            24
# 17   wynnea01            24
# 18   ryanja01            24
# 19  newsobo01            24
# 20  morgami01            24
# 21  henderi01            24
# 22  oroscje01            24
# 23  carltst01            23
# 24  maranra01            23
# 25  wallabo01            23
# 26  raineti01            23
# 27  dempsri01            23
# 28   rosepe01            23
# 29  griffcl01            23
# 30  niekrph01            23
# 31  oconnja01            23
# ...

# %% [markdown]
# 6) What is the distribution of debut months? *Hint:* Look at the `DATE` and [`EXTRACT`](https://www.postgresql.org/docs/current/static/functions-datetime.html#FUNCTIONS-DATETIME-EXTRACT) functions.

# %%
pd.read_sql_query('''SELECT EXTRACT(MONTH FROM debut) AS Month, COUNT(*) AS total_debuts FROM Master WHERE debut IS NOT NULL GROUP BY Month ORDER BY Month''',cnx)
# Out:
#    month  total_debuts
# 0    3.0            41
# 1    4.0          4711
# 2    5.0          2230
# 3    6.0          1893
# 4    7.0          1978
# 5    8.0          1943
# 6    9.0          5061
# 7   10.0           308

# %% [markdown]
# 7) What is the effect of table join order on mean salary for the players listed in the main (master) table? *Hint:* Perform two different queries, one that joins on playerID in the salary table and other that joins on the same column in the master table. You will have to use left joins for each since right joins are not currently supported with SQLalchemy.

# %%
pd.read_sql_query('''SELECT SUM(salary)/COUNT(*) FROM Master LEFT JOIN Salaries ON Master.playerid=Salaries.playerid''',cnx)
# Out:
#        ?column?
# 0  1.186508e+06

# %%
pd.read_sql_query('''SELECT SUM(salary)/COUNT(*) FROM Salaries LEFT JOIN Master ON Salaries.playerid=Master.playerid''',cnx)
# Out:
#        ?column?
# 0  1.864357e+06

# %% [markdown]
# The Master list has players that aren't in the salary table or who have null values in the salary table. So when you start with the master table and join the salary table into it, you have additional erroneous rows that affect the count. When you start with the salary table and only join where master matches, you never include those erroneous rows.

# %% [markdown]
# ### Part iii

# %%
import sqlite3
conn = sqlite3.connect('database.sqlite')
c = conn.cursor()

# %%
for row in c.execute('SELECT * FROM League LIMIT 10'):
        print(row)
# Out:
# (1, 1, 'Belgium Jupiler League')
# (1729, 1729, 'England Premier League')
# (4769, 4769, 'France Ligue 1')
# (7809, 7809, 'Germany 1. Bundesliga')
# (10257, 10257, 'Italy Serie A')
# (13274, 13274, 'Netherlands Eredivisie')
# (15722, 15722, 'Poland Ekstraklasa')
# (17642, 17642, 'Portugal Liga ZON Sagres')
# (19694, 19694, 'Scotland Premier League')
# (21518, 21518, 'Spain LIGA BBVA')

# %% [markdown]
# 1) Which team scored the most points when playing at home?

# %%
for row in c.execute('SELECT team_long_name, SUM(home_team_goal) AS total_goals FROM Match JOIN Team ON home_team_api_id=team_api_id GROUP BY home_team_api_id ORDER BY total_goals LIMIT 1'):
    print('Higest Scoring Home Team :', row[0], "\n", 'Scored: ', row[1], 'goals')
# Out:
# Higest Scoring Home Team : SpVgg Greuther Fürth
#  Scored:  10 goals

# %% [markdown]
# 2) Did this team also score the most points when playing away?

# %%
for row in c.execute('SELECT team_long_name, SUM(away_team_goal) AS total_goals FROM Match JOIN Team ON away_team_api_id=team_api_id GROUP BY away_team_api_id ORDER BY total_goals LIMIT 1'):
    print('Higest Scoring Away Team :', row[0], "\n", 'Scored: ', row[1], 'goals')
# Out:
# Higest Scoring Away Team : FC Metz
#  Scored:  5 goals

# %% [markdown]
# 3) How many matches resulted in a tie?

# %%
for row in c.execute('SELECT COUNT(*) FROM Match WHERE away_team_goal=home_team_goal'):
        print(row)
# Out:
# (6596,)

# %% [markdown]
# 4) How many players have Smith for their last name? How many have 'smith' anywhere in their name?

# %%
for row in c.execute('SELECT COUNT(*) FROM Player WHERE player_name LIKE "% Smith"'):
        print(row)
# Out:
# (15,)

# %%
for row in c.execute('SELECT COUNT(*) FROM Player WHERE player_name LIKE "%Smith%"'):
        print(row)
# Out:
# (18,)

# %% [markdown]
# 5) What was the median tie score? Use the value determined in the previous question for the number of tie games. Hint: PostgreSQL does not have a median function. Instead, think about the steps required to calculate a median and use the WITH command to store stepwise results as a table and then operate on these results.

# %%
tie_scores= []
for row in c.execute('SELECT away_team_goal FROM Match WHERE away_team_goal=home_team_goal'):
        tie_scores.append(row[0])

# %%
import numpy as np

# %%
np.median(tie_scores)
# Out:
# 1.0

# %% [markdown]
# 6) What percentage of players prefer their left or right foot? Hint: Calculate either the right or left foot, whichever is easier based on how you setup the problem.

# %%
for row in c.execute('SELECT COUNT(*) FROM (SELECT player_api_id FROM Player_Attributes WHERE preferred_foot="right" GROUP BY player_api_id) '):
    right_footed = row[0]

# %%
for row in c.execute('SELECT COUNT(*) FROM Player'):
    player_count = row[0]

# %%
# Rightfoot percent
np.round(right_footed*100/player_count)
# Out:
# 81.0

# %%
# Leftfoot percent
np.round(100 - right_footed*100/player_count)
# Out:
# 19.0
