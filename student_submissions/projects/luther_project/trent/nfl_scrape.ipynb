# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
from collections import defaultdict
from functools import partial, reduce
import pickle
path = !pwd

# %%
def soup_from_url(url):
    response = requests.get(url)
    page = response.text
    return BeautifulSoup(page, "lxml")

# %%
#Get list of teams and team links
soup = soup_from_url('https://www.pro-football-reference.com/teams')
team_links = [x.a for x in soup.find_all(attrs ={'data-stat' : 'team_name'})[1:]]
team_links = list(filter(None, team_links))
teams = [(x.text, x['href']) for x in team_links]

# %%
#Get team summary data
url = 'https://www.pro-football-reference.com{}'
dd = defaultdict(dict)
for t in teams:
    soup = soup_from_url(url.format(t[1]))
    for i, row in enumerate(soup.tbody.find_all('tr')[1:12]):
        year = 2016 - i
        dd[t[0]][year] = dict([(x['data-stat'], x.text) for x in row.find_all('td')][2:])

# %%
#Dump team summary data
with open('team_info.pkl', 'wb') as picklefile:
    pickle.dump(dd, picklefile)

# %%
#Get team penalty data
d = defaultdict(partial(defaultdict, dict))
penalty_keys = ['Number of Penalties', 
                'Yards Penalized', 
                'Delay of Game', 
                'False Start',
                'Offensive Holding',
                'Offensive Pass Interference',
                'Offsides',
                'Defensive Holding',
                'Illegal Contact',
                'Defensive Pass Interference',
                'Roughing the Passer',
                'Personal Foul',
                'Unnecessary Roughness', 
                'Unsportsmanlike Conduct',
                'Other']
for year in range(2006, 2017):
    soup = soup_from_url('http://www.footballdb.com/stats/penalties.html?yr={}'.format(year))
    for row in soup.tbody.find_all('tr'):
        penalties = [x.text for x in row.find_all('td')[1:]]
        d[row.a.text][year] = dict(zip(penalty_keys, penalties))

# %%
#Dump team penalty data
with open('penalties.pkl', 'wb') as picklefile:
    pickle.dump(d, picklefile)

# %%
#Helper methods for ratings parsing
def merge_2nd_and_3rd(l):
    l_ = l[:]
    l_[2:4] = [''.join(l_[2:4])]
    return l_


def is_week(s):
    return bool(re.match('WEEK.*', s))

def is_date(s):
    return bool(re.match(r'\w*, \w* \d\d?', s))

# %%
# 2016 Ratings
soup = soup_from_url('http://www.sportsmediawatch.com/nfl-tv-ratings-viewership-nbc-cbs-fox-espn-nfln-regular-season-playoffs/2')
l2 = [re.split('#', x.get_text(separator='#')) for x in soup.tbody.find_all('tr')]
l = []
week = None
for row in l2[2:]:
    if len(row) in {1, 2, 3} and is_week(row[0]):
        week = row[0]
    if week: #skips playoff games
        if len(row) == 9:
            row.append(week)
            l.append(row)
        elif len(row) == 10:
            row.append(week)
            l.append(merge_2nd_and_3rd(row))
labels = ['Window', 'Game', 'Net', 'Rtg.', '+/-', 'Vwrs.', '+/-', 'Strm.', '18-49', 'Date']
df = pd.DataFrame(l, columns=labels)
df.to_csv('ratings_2016.csv')

# %%
df.head(100)
# Out:
#        Window              Game        Net  Rtg.     +/-  Vwrs.     +/- Strm.  \
# 0         SNF            GB/DET        NBC  13.0     -6%  23.8M     -2%     —
# 1     Late DH     NYG/WSH (76%)        FOX  12.3     +3%  22.4M     +7%     —
# 2    Early DH     DAL/PHI (79%)        FOX  9.65     +7%  17.0M    +13%     —
# 3    Early DH      MIA/NE (61%)        CBS   9.2    -18%  16.6M    -11%     —
# 4     Late DH   Regional action        CBS   6.8    -34%  12.1M    -31%     —
# 5         SNF            KC/DEN        NBC  10.6     +2%  21.4M    +20%   81K
# 6         MNF           DET/DAL       ESPN  10.1     +7%  18.6M    +18%  260K
# 7    Early DH      GB/MIN (71%)        FOX  10.0     +8%  18.4M    +13%     —
# 8       TNF**           NYG/PHI  NBC, NFLN  10.6   +194%  17.9M   +154%  350K
# 9     Late DH       TB/NO (66%)        FOX   8.1    -48%  15.4M    -44%     —
# 10    Special           PIT/BAL       NFLN   6.5  no gm.  14.8M  no gm.     —
# 11     Single   Regional action        CBS   7.7    -25%  14.2M    -19%     —
# 12    Special           CIN/HOU       NFLN   3.2    -32%   6.3M    -23%     —
# 13    Late DH      NE/DEN (83%)        CBS  14.3     -2%  25.0M    even     —
# 14        SNF            TB/DAL        NBC  13.6    +30%  24.1M    +33%     —
# 15     Single     DET/NYG (48%)        FOX  10.8    -26%  18.7M    -25%     —
# 16   Early DH   Regional action        CBS   8.8    +28%  15.0M    +33%     —
# 17      TNF**            LA/SEA  NBC, NFLN   8.8   +132%  14.7M   +144%  321K
# 18        MNF           CAR/WSH       ESPN   6.8     +1%  11.2M     +3%  201K
# 19    Special           NYJ/MIA       NFLN   2.5    -42%   4.4M    -41%     —
# 20        SNF           DAL/NYG        NBC  14.9    +21%  26.5M    +26%  208K
# 21    Late DH      SEA/GB (67%)        FOX  14.4    -13%  25.3M    -13%     —
# 22     Single   Regional action        CBS  11.2     +3%  19.1M     +3%     —
# 23      TNF**            OAK/KC  NBC, NFLN  10.5    +91%  17.4M    +99%  417K
# 24        MNF            BAL/NE       ESPN   7.8     +5%  12.9M    +12%  253K
# 25   Early DH     WSH/PHI (68%)        FOX   7.5    -16%  12.3M    -19%     —
# 26    Late DH     NYG/PIT (85%)        FOX  14.6    -10%  25.4M    -11%     —
# 27        TNF           DAL/MIN  NBC, NFLN  12.8    +16%  21.8M    +22%  479K
# 28     Single   Regional action        CBS  10.8     +6%  18.5M     +8%     —
# 29        SNF           CAR/SEA        NBC  10.2     -8%  17.8M     -7%     —
# ..        ...               ...        ...   ...     ...    ...     ...   ...
# 70        MNF           HOU/DEN       ESPN   6.7    -14%  11.2M     -8%  236K
# 71  Special**   NYG/LA (London)       NFLN   2.4       —   3.7M   +125%     —
# 72    Late DH      DAL/GB (86%)        FOX  15.8     +9%  28.0M    +12%     —
# 73     Single   Regional action        CBS  10.2     -4%  17.2M     -4%     —
# 74        TNF            DEN/SD  CBS, NFLN   8.7     -6%  14.5M     -2%     —
# 75        SNF           IND/HOU        NBC   8.1    -38%  13.6M    -40%     —
# 76   Early DH     PHI/WSH (39%)        FOX   7.7    -29%  13.2M    -28%     —
# 77        MNF            NYJ/AZ       ESPN   5.2    -40%   8.4M    -40%  200K
# 78    Late DH     CIN/DAL (80%)        CBS  12.1    -20%  21.3M    -18%     —
# 79     Single     ATL/DEN (43%)        FOX   9.4    -14%  16.5M     -9%     —
# 80      SNF**            NYG/GB        NBC   9.3    -21%  16.6M    -15%     —
# 81   Early DH   Regional action        CBS   9.0     +8%  15.2M    +12%     —
# 82        TNF             AZ/SF  CBS, NFLN   7.4    -22%  12.1M    -20%     —
# 83        MNF            TB/CAR       ESPN   5.6    -27%   9.1M    -26%  214K
# 84    Late DH      DAL/SF (84%)        FOX  13.1    -13%  22.7M    -12%     —
# 85        SNF            KC/PIT        NBC  10.3    -27%  18.1M    -25%  116K
# 86     Single   Regional action        CBS   9.4     -2%  16.4M     +4%     —
# 87        MNF           NYG/MIN       ESPN   8.0    -11%  13.2M     -9%  262K
# 88   Early DH     SEA/NYJ (43%)        FOX   6.7    -14%  11.2M    -13%     —
# 89      TNF**           MIA/CIN       NFLN   4.8    -59%   7.9M    -59%     —
# 90    Special  IND/JAX (London)        CBS   4.8    -25%   7.7M    -22%     —
# 91    Late DH     PIT/PHI (52%)        CBS  12.6     -2%  22.0M     -1%     —
# 92        SNF           CHI/DAL        NBC  11.7    -11%  20.6M     -7%  125K
# 93     Single     WSH/NYG (31%)        FOX  11.1     +3%  19.2M     +5%     —
# 94        TNF            HOU/NE  CBS, NFLN  10.6     +1%  17.5M     +4%  398K
# 95   Early DH   Regional action        CBS   8.0    -13%  13.1M    -13%     —
# 96      MNF**            ATL/NO       ESPN   4.9    -41%   8.0M    -40%  209K
# 97        SNF            GB/MIN        NBC  12.7    -16%  22.8M    -14%  202K
# 98    Late DH     IND/DEN (74%)        CBS  12.2    -21%  21.4M    -21%     —
# 99     Single     DAL/WSH (36%)        FOX  11.0    +12%  19.2M    +15%     —
#
#    18-49            Date
# 0      —  WEEK SEVENTEEN
# 1    7.4  WEEK SEVENTEEN
# 2      —  WEEK SEVENTEEN
# 3      —  WEEK SEVENTEEN
# 4      —  WEEK SEVENTEEN
# 5    6.4    WEEK SIXTEEN
# 6    5.8    WEEK SIXTEEN
# 7      —    WEEK SIXTEEN
# 8    5.1    WEEK SIXTEEN
# 9      —    WEEK SIXTEEN
# 10   4.5    WEEK SIXTEEN
# 11     —    WEEK SIXTEEN
# 12   1.9    WEEK SIXTEEN
# 13     —    WEEK FIFTEEN
# 14   8.1    WEEK FIFTEEN
# 15     —    WEEK FIFTEEN
# 16     —    WEEK FIFTEEN
# 17   4.3    WEEK FIFTEEN
# 18   3.6    WEEK FIFTEEN
# 19   1.3    WEEK FIFTEEN
# 20   8.7   WEEK FOURTEEN
# 21     —   WEEK FOURTEEN
# 22     —   WEEK FOURTEEN
# 23   5.6   WEEK FOURTEEN
# 24   4.2   WEEK FOURTEEN
# 25     —   WEEK FOURTEEN
# 26     —   WEEK THIRTEEN
# 27   6.8   WEEK THIRTEEN
# 28     —   WEEK THIRTEEN
# 29   6.1   WEEK THIRTEEN
# ..   ...             ...
# 70   3.7      WEEK SEVEN
# 71     —      WEEK SEVEN
# 72     —        WEEK SIX
# 73     —        WEEK SIX
# 74   4.7        WEEK SIX
# 75   4.9        WEEK SIX
# 76     —        WEEK SIX
# 77   3.0        WEEK SIX
# 78     —       WEEK FIVE
# 79     —       WEEK FIVE
# 80   5.9       WEEK FIVE
# 81     —       WEEK FIVE
# 82   4.1       WEEK FIVE
# 83   3.3       WEEK FIVE
# 84     —       WEEK FOUR
# 85   6.7       WEEK FOUR
# 86     —       WEEK FOUR
# 87   4.7       WEEK FOUR
# 88     —       WEEK FOUR
# 89   3.0       WEEK FOUR
# 90     —       WEEK FOUR
# 91   7.1      WEEK THREE
# 92   7.6      WEEK THREE
# 93     —      WEEK THREE
# 94   6.1      WEEK THREE
# 95     —      WEEK THREE
# 96   3.1      WEEK THREE
# 97   8.2        WEEK TWO
# 98   7.0        WEEK TWO
# 99     —        WEEK TWO
#
# [100 rows x 10 columns]

# %%
# 2015 Ratings
soup = soup_from_url('http://www.sportsmediawatch.com/nfl-tv-ratings-viewership-nbc-cbs-fox-espn-nfln-regular-season-playoffs/3')
l = []
l2 = [re.split('#', x.get_text(separator='#')) for x in soup.tbody.find_all('tr')]
for row in l2:
    if len(row) == 1:
        week = row[0].title()
    if len(row) == 8:
        row.pop(1)
        row.append(week)
        l.append(row) 
labels = ['Game', 'Window', 'Net', 'Rtg.', '+/-', 'Vwrs.', '+/-', 'Date']
df = pd.DataFrame(l, columns=labels)
df.to_csv(path[0] + '/ratings_2015.csv')

# %%
df.head(100)
# Out:
#                        Game                   Window        Net  Rtg.     +/-  \
# 0         Steelers/Patriots              NFL Kickoff        NBC  16.2     +3%
# 1            Giants/Cowboys      Sun. Night Football        NBC  15.4    +10%
# 2      Ravens/Broncos (80%)       Doubleheader Gm. 2        CBS  13.5    -14%
# 3       Packers/Bears (47%)             Singleheader        FOX  11.6    +17%
# 4           Regional action       Doubleheader Gm. 1        CBS     —       —
# 5             Vikings/49ers      Mon. Night Football       ESPN   8.8    +24%
# 6            Eagles/Falcons      Mon. Night Football       ESPN   8.5     +1%
# 7            Cowboys/Eagles       Doubleheader Gm. 2        FOX  15.5     +8%
# 8          Seahawks/Packers      Sun. Night Football        NBC  15.1    +17%
# 9            Broncos/Chiefs      Thu. Night Football  CBS, NFLN  12.9     +2%
# 10          Regional action             Singleheader        CBS     —       —
# 11     Falcons/Giants (32%)       Doubleheader Gm. 1        FOX     —       —
# 12               Jets/Colts      Mon. Night Football       ESPN   8.1    -12%
# 13     Bears/Seahawks (76%)       Doubleheader Gm. 2        CBS  12.9    -18%
# 14            Broncos/Lions    Sunday Night Football        NBC  13.1    +10%
# 15    Falcons/Cowboys (46%)             Singleheader        FOX     —       —
# 16             Wash./Giants      Thu. Night Football  CBS, NFLN  10.5    +40%
# 17          Regional action       Doubleheader Gm. 1        CBS     —       —
# 18           Chiefs/Packers    Monday Night Football       ESPN   8.3     -1%
# 19      Packers/49ers (57%)       Doubleheader Gm. 2        FOX  15.0    even
# 20           Cowboys/Saints    Sunday Night Football        NBC  14.1     +4%
# 21          Ravens/Steelers      Thu. Night Football  CBS, NFLN  11.8    +16%
# 22          Regional action             Singleheader        CBS     —       —
# 23           Lions/Seahawks    Monday Night Football       ESPN   9.0     +2%
# 24       Giants/Bills (68%)       Doubleheader Gm. 1        FOX     —       —
# 25            Jets/Dolphins     International Series        CBS     —       —
# 26   Patriots/Cowboys (81%)       Doubleheader Gm. 2        CBS  15.2    +32%
# 27             49ers/Giants    Sunday Night Football        NBC  11.8     +1%
# 28   Seahawks/Bengals (39%)             Singleheader        FOX     —       —
# 29             Colts/Texans  Thursday Night Football  CBS, NFLN   9.5     -3%
# ..                      ...                      ...        ...   ...     ...
# 70         Panthers/Cowboys        Thanksgiving Late        CBS  14.3     +1%
# 71            Bears/Packers       Thanksgiving Prime        NBC  13.8    +21%
# 72        Steelers/Seahawks       Doubleheader Gm. 2        CBS  15.4     -1%
# 73             Eagles/Lions       Thanksgiving Early        FOX  12.3    -10%
# 74         Patriots/Broncos    Sunday Night Football        NBC  14.6    +11%
# 75       Giants/Wash. (32%)             Singleheader        FOX  12.3     +1%
# 76            Ravens/Browns    Monday Night Football       ESPN   6.5     -3%
# 77          Regional action       Doubleheader Gm. 1        CBS   6.0    -28%
# 78    Panthers/Saints (61%)       Doubleheader Gm. 2        FOX  16.3     -7%
# 79           Colts/Steelers    Sunday Night Football        NBC  11.1    -11%
# 80            Packers/Lions  Thursday Night Football  CBS, NFLN  11.0  no gm.
# 81        Jets/Giants (39%)             Singleheader        CBS  10.2     +6%
# 82   Seahawks/Vikings (42%)       Doubleheader Gm. 1        FOX   9.4    +13%
# 83            Cowboys/Wash.    Monday Night Football       ESPN   8.7    +18%
# 84          Cowboys/Packers       Doubleheader Gm. 2        FOX  16.5     +6%
# 85          Patriots/Texans    Sunday Night Football        NBC  12.3     -4%
# 86          Regional action             Singleheader        CBS  10.9     +3%
# 87   Falcons/Panthers (34%)       Doubleheader Gm. 1        FOX   8.9     +3%
# 88          Giants/Dolphins    Monday Night Football       ESPN   7.4    -13%
# 89        Vikings/Cardinals  Thursday Night Football       NFLN   5.5    even
# 90   Broncos/Steelers (86%)       Doubleheader Gm. 2        CBS  14.5     -8%
# 91    Panthers/Giants (52%)             Singleheader        FOX  14.5    +31%
# 92         Cardinals/Eagles    Sunday Night Football        NBC  10.5    -27%
# 93             Lions/Saints    Monday Night Football       ESPN   6.7     -6%
# 94             Jets/Cowboys   TNF (Saturday edition)       NFLN   4.3       —
# 95          Buccaneers/Rams  Thursday Night Football       NFLN   3.8    -19%
# 96  Packers/Cardinals (92%)       Doubleheader Gm. 2        FOX  15.5     +2%
# 97           Vikings/Giants    Sunday Night Football        NBC  10.4    -10%
# 98          Regional action             Singleheader        CBS     —       —
# 99   Panthers/Falcons (54%)       Doubleheader Gm. 1        FOX     —       —
#
#     Vwrs.     +/-           Date
# 0   27.4M     +1%       Week One
# 1   26.8M    +12%       Week One
# 2   23.3M    -17%       Week One
# 3   20.1M    +22%       Week One
# 4   14.9M     +6%       Week One
# 5   14.3M    +24%       Week One
# 6   13.6M     -1%       Week One
# 7   27.2M     +9%       Week Two
# 8   26.4M    +19%       Week Two
# 9   21.1M     +2%       Week Two
# 10  16.7M    -14%       Week Two
# 11  15.3M    +17%       Week Two
# 12  12.5M    -16%       Week Two
# 13  22.1M    -19%     Week Three
# 14  22.1M    +11%     Week Three
# 15  18.3M    -11%     Week Three
# 16  16.9M    +42%     Week Three
# 17  15.1M     +4%     Week Three
# 18  13.5M     +2%     Week Three
# 19  25.9M    even      Week Four
# 20  24.2M     +5%      Week Four
# 21  19.4M    +19%      Week Four
# 22  15.8M    +34%      Week Four
# 23  14.4M    even      Week Four
# 24  12.8M    -15%      Week Four
# 25   9.9M  no gm.      Week Four
# 26  26.1M    +33%      Week Five
# 27  19.6M     +1%      Week Five
# 28  18.0M     -7%      Week Five
# 29  15.1M     -9%      Week Five
# ..    ...     ...            ...
# 70  32.5M     +1%    Week Twelve
# 71  27.8M    +21%    Week Twelve
# 72  26.6M     +1%    Week Twelve
# 73  25.4M    -14%    Week Twelve
# 74  25.2M    +13%    Week Twelve
# 75  20.5M     -1%    Week Twelve
# 76  10.1M     -7%    Week Twelve
# 77   9.8M    -25%    Week Twelve
# 78  28.6M     -7%  Week Thirteen
# 79  19.2M     -9%  Week Thirteen
# 80  17.8M  no gm.  Week Thirteen
# 81  17.2M    +10%  Week Thirteen
# 82  15.4M    +13%  Week Thirteen
# 83  14.2M    +20%  Week Thirteen
# 84  28.9M    +11%  Week Fourteen
# 85  21.0M     -1%  Week Fourteen
# 86  18.6M     +6%  Week Fourteen
# 87  15.2M    +11%  Week Fourteen
# 88  11.5M    -17%  Week Fourteen
# 89   8.7M     -4%  Week Fourteen
# 90  25.0M     -6%   Week Fifteen
# 91  25.0M    +34%   Week Fifteen
# 92  18.1M    -25%   Week Fifteen
# 93  10.9M     -2%   Week Fifteen
# 94   7.4M       —   Week Fifteen
# 95   6.0M    -22%   Week Fifteen
# 96  27.8M     +7%   Week Sixteen
# 97  17.9M     -7%   Week Sixteen
# 98  17.6M     +9%   Week Sixteen
# 99  16.2M     -1%   Week Sixteen
#
# [100 rows x 8 columns]

# %%
#2014 Ratings
soup = soup_from_url('http://www.sportsmediawatch.com/nfl-tv-ratings-viewership-nbc-cbs-fox-espn-nfln-regular-season-playoffs/4/')
l2 = [re.split('#', x.get_text(separator='#')) for x in soup.tbody.find_all('tr')]
l2[0].append('Date')
for row in l2[1:]:
    if is_date(row[0]):
        date = row[0]
        continue
    if len(row) > 6:
        row.append(date)
l2 = [x for x in l2 if len(x) > 6]
df = pd.DataFrame(l2[1:], columns=['Window', 'Game', 'Net', 'Rtg.', '+/-', 'Vwrs.', '+/-', 'Date'])
df = df[:107]
df.to_csv(path[0] + '/ratings_2014.csv')
df.head(20)
# Out:
#       Window                     Game        Net  Rtg.   +/-   Vwrs.   +/-  \
# 0    Kickoff         Packers/Seahawks        NBC  15.5   +4%  26.91M   +7%
# 1   National      49ers/Cowboys (89%)        FOX  15.7   -5%  28.00M   -2%
# 2        SNF            Colts/Broncos        NBC  13.9   -8%  23.69M   -7%
# 3     Single          Regional action        CBS   9.9   +4%  16.50M   +6%
# 4   Regional     Saints/Falcons (49%)        FOX   8.2   -8%  14.10M   -4%
# 5        MNF             Giants/Lions       ESPN   8.4  -17%  13.73M  -17%
# 6        MNF       Cardinals/Chargers       ESPN   7.1  even  11.52M   +5%
# 7        TNF          Steelers/Ravens  CBS, NFLN  12.7  +84%  20.77M  +89%
# 8   National     Chiefs/Broncos (56%)        CBS  14.4   -9%  24.94M   -6%
# 9        SNF              Bears/49ers        NBC  12.9   +6%  22.16M   +8%
# 10    Single  Seahawks/Chargers (25%)        FOX  11.3  -12%  19.41M  -11%
# 11  Regional          Regional action        CBS   7.8   -2%  13.12M   +5%
# 12       MNF             Eagles/Colts       ESPN   9.2   +1%  14.89M   +4%
# 13       TNF       Buccaneers/Falcons  CBS, NFLN   7.5   +7%  11.88M   +7%
# 14  National   Broncos/Seahawks (89%)        CBS  15.8   +3%  27.29M   +7%
# 15    Single    49ers/Cardinals (27%)        FOX  11.8   -6%  20.56M   -2%
# 16       SNF        Steelers/Panthers        NBC  11.8   -3%  19.67M   -4%
# 17  Regional          Regional action        CBS   8.7  +42%  14.54M   N/A
# 18       MNF               Bears/Jets       ESPN   8.4   -6%  13.27M   -5%
# 19       TNF        Giants/Washington  CBS, NFLN  10.2  +92%  16.30M  +96%
#
#                       Date
# 0    Thursday, September 4
# 1      Sunday, September 7
# 2      Sunday, September 7
# 3      Sunday, September 7
# 4      Sunday, September 7
# 5      Monday, September 8
# 6      Monday, September 8
# 7   Thursday, September 11
# 8     Sunday, September 14
# 9     Sunday, September 14
# 10    Sunday, September 14
# 11    Sunday, September 14
# 12    Monday, September 15
# 13  Thursday, September 18
# 14    Sunday, September 21
# 15    Sunday, September 21
# 16    Sunday, September 21
# 17    Sunday, September 21
# 18    Monday, September 22
# 19  Thursday, September 25

# %%
# Injuries Data

data = []
url = 'http://www.prosportstransactions.com/football/Search/SearchResults.php?Player=&Team=&BeginDate=2006-09-01&EndDate=2017-09-28&ILChkBx=yes&submit=Search'
soup = soup_from_url(url)
page_indices = list(range(25, 10501, 25))
pre_url = "http://www.prosportstransactions.com/football/Search/SearchResults.php?Player=&Team=&BeginDate=2006-09-01&EndDate=2017-09-28&ILChkBx=yes&submit=Search&start={}"
for i in page_indices:
    url = pre_url.format(i)
    soup = soup_from_url(url)
    for row in soup.table.find_all('tr'):
        data.append([x.text for x in row.find_all('td')])  
df = pd.DataFrame(data)
df.to_csv(path[0] + '/injuries.csv')

# %% [markdown]
# ***Getting the data for scores by year***

# %%
base_url = 'https://www.pro-football-reference.com/years/2016/week_{}.htm'
l = []
for week in list(range(1, 18)):
    url = base_url.format(week)
    soup = soup_from_url(url)
    l2 = [[re.split('#', x.get_text(separator='#')) for x in y.find_all('td')] for y in soup.find_all(class_='teams')]
    l += [(week, x[0][0], x[1][0], x[2][0], x[4][0], x[5][0]) for x in l2]

# %%
games_2016 = pd.DataFrame(l,columns=['week', 'date', 'team_1', 'team_1_score', 'team_2', 'team_2_score'])
games_2016.head(20)
games_2016.to_csv('games_2016.csv')

# %%
base_url = 'https://www.pro-football-reference.com/years/2015/week_{}.htm'
l = []
for week in list(range(1, 18)):
    url = base_url.format(week)
    soup = soup_from_url(url)
    l2 = [[re.split('#', x.get_text(separator='#')) for x in y.find_all('td')] for y in soup.find_all(class_='teams')]
    l += [(week, x[0][0], x[1][0], x[2][0], x[4][0], x[5][0]) for x in l2]

# %%
games_2015 = pd.DataFrame(l,columns=['week', 'date', 'team_1', 'team_1_score', 'team_2', 'team_2_score'])
games_2015.to_csv('games_2015.csv')

# %%
base_url = 'https://www.pro-football-reference.com/years/2014/week_{}.htm'
l = []
for week in list(range(1, 18)):
    url = base_url.format(week)
    soup = soup_from_url(url)
    l2 = [[re.split('#', x.get_text(separator='#')) for x in y.find_all('td')] for y in soup.find_all(class_='teams')]
    l += [(week, x[0][0], x[1][0], x[2][0], x[4][0], x[5][0]) for x in l2]

# %%
games_2014 = pd.DataFrame(l,columns=['week', 'date', 'team_1', 'team_1_score', 'team_2', 'team_2_score'])
games_2014.to_csv('games_2014.csv')

# %%
base_url = 'https://www.pro-football-reference.com/years/2013/week_{}.htm'
l = []
for week in list(range(1, 18)):
    url = base_url.format(week)
    soup = soup_from_url(url)
    l2 = [[re.split('#', x.get_text(separator='#')) for x in y.find_all('td')] for y in soup.find_all(class_='teams')]
    l += [(week, x[0][0], x[1][0], x[2][0], x[4][0], x[5][0]) for x in l2]

# %%
games_2013 = pd.DataFrame(l,columns=['week', 'date', 'team_1', 'team_1_score', 'team_2', 'team_2_score'])
games_2013.to_csv('games_2013.csv')
