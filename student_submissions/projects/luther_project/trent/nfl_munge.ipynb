# %%
import requests
import numpy as np
import re
from bs4 import BeautifulSoup
import pandas as pd
from collections import defaultdict, Counter
from functools import partial, reduce
from datetime import datetime, date
import pickle
import math
path = !pwd
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 100

# %%
abbrs =   { 'AZ' : 'Arizona Cardinals',
            'ARI' : 'Arizona Cardinals',
            'ATL' : 'Atlanta Falcons',
            'BAL' : 'Baltimore Ravens',
            'BUF' : 'Buffalo Bills',
            'CAR' : 'Carolina Panthers',
            'CHI' : 'Chicago Bears',
            'CIN' : 'Cincinnati Bengals',
            'CLE' : 'Cleveland Browns',
            'DAL' : 'Dallas Cowboys',
            'DEN' : 'Denver Broncos',
            'DET': 'Detroit Lions',
            'GB' : 'Green Bay Packers',
            'HOU' : 'Houston Texans',
            'IND' : 'Indianapolis Colts',
            'JAX' : 'Jacksonville Jaguars',
            'JAC' : 'Jacksonville Jaguars',
            'KC' : 'Kansas City Chiefs',
            'LA' : 'Los Angeles Rams',
            'STL' : 'Los Angeles Rams',
            'MIA' : 'Miami Dolphins',
            'MIN' : 'Minnesota Vikings',
            'NE' : 'New England Patriots',
            'NO' : 'New Orleans Saints',
            'NYG' : 'New York Giants',
            'NYJ' : 'New York Jets',
            'OAK' : 'Oakland Raiders',
            'PHI' : 'Philadelphia Eagles',
            'PIT' : 'Pittsburgh Steelers',
            'SD' : 'San Diego Chargers',
            'SF' : 'San Francisco 49ers',
            'SEA' : 'Seattle Seahawks',
            'TB' : 'Tampa Bay Buccaneers',
            'TEN' : 'Tennessee Titans',
            'WAS' : 'Washington Redskins',
            'WSH' : 'Washington Redskins',
            'Chiefs' : 'Kansas City Chiefs',
            'Lions' : 'Detroit Lions',
            'Jets' : 'New York Jets',
            'Dolphins' : 'Miami Dolphins',
            'Texans' : 'Houston Texans',
            'Ravens' : 'Baltimore Ravens',
            'Saints' : 'New Orleans Saints',
            'Colts' : 'Indianapolis Colts',
            'Raiders' : 'Oakland Raiders',
            'Cardinals' : 'Arizona Cardinals',
            'Titans' : 'Tennessee Titans',
            'Vikings' : 'Minnesota Vikings',
            'Seahawks' : 'Seattle Seahawks',
            'Browns' : 'Cleveland Browns',
            'Panthers' : 'Carolina Panthers',
            'Chargers' : 'San Diego Chargers',
            'Rams' : 'Los Angeles Rams',
            'Wash.' : 'Washington Redskins',
            'Cowboys' : 'Dallas Cowboys',
            'Patriots' : 'New England Patriots',
            'Packers' : 'Green Bay Packers',
            'Eagles' : 'Philadelphia Eagles',
            'Washington' : 'Washington Redskins',
            'Bills' : 'Buffalo Bills',
            'Bengals' : 'Cincinnati Bengals',
            'Steelers' : 'Pittsburgh Steelers',
            'Falcons' : 'Atlanta Falcons',
            'Giants' : 'New York Giants',
            'Broncos' : 'Denver Broncos',
            'Bears' : 'Chicago Bears',
            'Jaguars' : 'Jacksonville Jaguars',
            'Buccaneers' : 'Tampa Bay Buccaneers',
            '49ers' : 'San Francisco 49ers'
          }

team_names_long = defaultdict(str)
team_names_long.update(abbrs)

# %%
def sum_of_naughties(c):
    return sum(c[p] for p in naughties)

def sum_of_super_naughties(c):
    return sum(c[p] for p in super_naughties)

naughties = {'CLIPPING',
             'DEFENSIVE PASS INTERFERENCE',
             'DISQUALIFICATION',
             'FACE MASK (15 YARDS)',
             'HORSE COLLAR TACKLE',
             'ILLEGAL BLINDSIDE BLOCK',
             'ILLEGAL BLOCK ABOVE THE WAIST',
             'ILLEGAL CONTACT',
             'ILLEGAL USE OF HANDS',
             'NEUTRAL ZONE INFRACTION',
             'PERSONAL FOUL',
             'ROUGHING THE KICKER',
             'ROUGHING THE PASSER',
             'RUNNING INTO THE KICKER',
             'TAUNTING',
             'TRIPPING',
             'UNNECESSARY ROUGHNESS',
             'UNSPORTSMANLIKE CONDUCT'}

super_naughties = {'UNSPORTSMANLIKE CONDUCT',
                   'UNNECESSARY ROUGHNESS',
                   'ROUGHING THE PASSER',
                   'PERSONAL FOUL',
                   'DISQUALIFICATION'}

# %%
words = ["zero", "one", "two", "three", "four", "five", "six", "seven", "eight",
        "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen",
        "sixteen", "seventeen", "eighteen", "nineteen"]
numbers = list(range(20))
numbers_dict = dict(zip(words, numbers))

def week_to_num(s):
    return numbers_dict[s.lower().split(' ')[-1]] 

def scrub_teams(s):
    if s.lower() == 'regional action':
        return [np.nan]
    s = str(re.sub(r'\(.*\)', '', s))
    s = str(re.sub(r' ', '', s))
    return re.split('/', s)

def get_team_name(team_abb):
    return team_names_long[team_abb]

# %%
def scrub_2014_date(d):
    d = reduce(string_cat, [d.split(' ')[1], ' ', d.split(' ')[2].zfill(2), ' 2014'])
    return datetime.strptime(d, '%B %d %Y')

# %%
def viewers_to_num(n):
    n = n.replace('.', '')
    return int(n[:-1])*(10**6)

# %%
def team_in_game(t, row):
    if t == row['team1']:
        return 1
    elif t == row['team2']:
        return 2
    return 0

# %%
def my_datetime(d):
    l = d.split(' ')
    if len(l[1]) == 2:
        d = ' '.join([l[0], '0' + l[1], l[2]])
    return datetime.strptime(d, '%b %d, %Y')

# %%
def get_best_rank(teams):
    x, y = teams
    return min(team_ranks[x], team_ranks[y])

# %%
def union(a, b):
    return set(a) | set(b)

# %%
def string_cat(a, b):
    return str(a) + str(b)

# %%
def did_team1_win(row):
    return int(row['team1_score'] > row['team2_score'])

def did_team2_win(row):
    return int(row['team2_score'] > row['team1_score'])

# %%
def fill_win_columns(df):
    df['team1_won'] = df.apply(did_team1_win, axis=1)
    df['team2_won'] = df.apply(did_team2_win, axis=1)

# %%
def align_teams(row):
    if row.team1 != row.team_1:
        t1s = row.team_2_score
        t2s = row.team_1_score
        row['team1_score'] = t1s
        row['team2_score'] = t2s
    else:
        row['team1_score'] = row.team_1_score
        row['team2_score'] = row.team_2_score
    return row

# %%
def make_datetime(t):
    return datetime.strptime(t, '%Y-%m-%d')

# %%
def set_up_ratings(df, date_is_week):
    df.rename(columns={'Window' : 'program', 
                        'Game' : 'teams', 
                        'Date' : 'week', 
                        'Net' : 'network',
                        '+/-' : 'ratings diff',
                        '+/-.1' : 'viewers diff',
                        'Rtg.' : 'rating',
                        'Vwrs.' : 'viewers'}, inplace=True)
    if date_is_week:
        df['week'] = df['week'].apply(week_to_num)
    else:
        df.rename(columns={'week' : 'date'}, inplace=True)
        df['date'] = df['date'].apply(scrub_2014_date)
    df['teams'] = df['teams'].apply(scrub_teams)
    df['teams'] = df['teams'].apply(lambda x: frozenset({get_team_name(y) for y in x}))
    if date_is_week:
        df = df[['program', 'teams', 'network', 'rating', 'ratings diff', 'viewers', 'viewers diff', 'week']]
    else:
        df = df[['program', 'teams', 'network', 'rating', 'ratings diff', 'viewers', 'viewers diff', 'date']]
    return df

r16 = set_up_ratings(pd.read_csv('ratings_2016.csv',index_col=0), True)
r15 = set_up_ratings(pd.read_csv('ratings_2015.csv',index_col=0), True)
r14 = set_up_ratings(pd.read_csv('ratings_2014.csv',index_col=0), False) 

r16['year'] = 2016
r15['year'] = 2015
r14['year'] = 2014

# %%
def date_to_weeknum_2014(d):
    d = datetime.strptime(str(d), '%Y-%m-%d %H:%M:%S')
    start = datetime.strptime('2014-09-04', '%Y-%m-%d')
    return (d-start).days//7 + 1

# %%
r14['week'] = r14['date'].apply(date_to_weeknum_2014)
r14 = r14[['program', 'teams', 'network', 'rating', 'ratings diff', 'viewers', 'viewers diff', 'week']]

# %%
rtgs = pd.concat([r14, r15, r15])
rtgs.head()
# Out:
#   network   program rating ratings diff  \
# 0     NBC   Kickoff   15.5          +4%
# 1     FOX  National   15.7          -5%
# 2     NBC       SNF   13.9          -8%
# 3     CBS    Single    9.9          +4%
# 4     FOX  Regional    8.2          -8%
#
#                                    teams viewers viewers diff  week  year
# 0  (Seattle Seahawks, Green Bay Packers)  26.91M          +7%     1   NaN
# 1  (Dallas Cowboys, San Francisco 49ers)  28.00M          -2%     1   NaN
# 2   (Denver Broncos, Indianapolis Colts)  23.69M          -7%     1   NaN
# 3                                     ()  16.50M          +6%     1   NaN
# 4  (New Orleans Saints, Atlanta Falcons)  14.10M          -4%     1   NaN

# %% [markdown]
# I didn't end up using ratings data, used google search data instead

# %%
i16 = pd.read_csv('games_2016.csv', index_col = 0)
i15 = pd.read_csv('games_2015.csv', index_col = 0)
i14 = pd.read_csv('games_2014.csv', index_col = 0)
i13 = pd.read_csv('games_2013.csv', index_col = 0)

i16['teams'] = i16.apply(lambda row: frozenset({row[2], row[4]}), axis=1)
i15['teams'] = i15.apply(lambda row: frozenset({row[2], row[4]}), axis=1)
i14['teams'] = i14.apply(lambda row: frozenset({row[2], row[4]}), axis=1)
i13['teams'] = i13.apply(lambda row: frozenset({row[2], row[4]}), axis=1)

i16['date'] = i16['date'].apply(my_datetime)
i15['date'] = i15['date'].apply(my_datetime)
i14['date'] = i14['date'].apply(my_datetime)
i13['date'] = i13['date'].apply(my_datetime)

i13.head()
# Out:
#    week       date                team_1  team_1_score              team_2  \
# 0     1 2013-09-05      Baltimore Ravens            27      Denver Broncos
# 1     1 2013-09-08       Oakland Raiders            17  Indianapolis Colts
# 2     1 2013-09-08        Miami Dolphins            23    Cleveland Browns
# 3     1 2013-09-08    Cincinnati Bengals            21       Chicago Bears
# 4     1 2013-09-08  New England Patriots            23       Buffalo Bills
#
#    team_2_score                                  teams
# 0            49     (Denver Broncos, Baltimore Ravens)
# 1            21  (Oakland Raiders, Indianapolis Colts)
# 2            10     (Cleveland Browns, Miami Dolphins)
# 3            24    (Cincinnati Bengals, Chicago Bears)
# 4            21  (Buffalo Bills, New England Patriots)

# %%
#this compiles the play by play data (downloaded in a csv) for each game into the relevant summary statitics

def get_game_df(df):
    rows = []
    for i in df.GameId.unique():
        g = df[df.GameId == i]
        g.IsFumble.replace(['0','OPP'], 0, inplace=True)
        g.IsFumble.replace('1', 1, inplace=True)
        date = make_datetime(g.GameDate.unique()[0])
        t1, t2 = [get_team_name(x) for x in g.OffenseTeam.unique() if get_team_name(x)]

        p = g[g.IsPenalty == 1]
        t1pen = Counter(p[p.PenaltyTeam.apply(get_team_name) == t1].PenaltyType)
        t2pen = Counter(p[p.PenaltyTeam.apply(get_team_name) == t2].PenaltyType)

        o1 = g[g.OffenseTeam.apply(get_team_name) == t1]
        t1pass = sum(o1.IsPass)/(sum(o1.IsPass) + sum(o1.IsRush))
        t1td = sum(o1.IsTouchdown)
        t1avgyd = np.mean(o1.Yards)

        o2 = g[g.OffenseTeam.apply(get_team_name) == t2]
        t2pass = sum(o2.IsPass)/(sum(o2.IsPass) + sum(o2.IsRush))
        t2td = sum(o2.IsTouchdown)
        t2avgyd = np.mean(o2.Yards)

        d1 = g[g.DefenseTeam.apply(get_team_name) == t1]
        t1sack = sum(d1.IsSack)
        t1int = sum(d1.IsInterception)
        t1fumb = sum(d1.IsFumble)

        d2 = g[g.DefenseTeam.apply(get_team_name) == t2]
        t2sack = sum(d2.IsSack)
        t2int = sum(d2.IsInterception)
        t2fumb = sum(d2.IsFumble)

        rows.append([i, date, t1, t1pen, t1pass, t1td, t1avgyd, t1sack, t1int, t1fumb, 
                           t2, t2pen, t2pass, t2td, t2avgyd, t2sack, t2int, t2fumb,
                    frozenset({t1, t2})])

    return pd.DataFrame(rows, columns=['gameid',
                                      'date',
                                      'team1',
                                      'team1_penalties',
                                      'team1_passratio',
                                      'team1_TD',
                                      'team1_avgYd',
                                      'team1_sacks',
                                      'team1_int',
                                      'team1_fmbl',
                                      'team2',
                                      'team2_penalties',
                                      'team2_passratio',
                                      'team2_TD',
                                      'team2_avgYd',
                                      'team2_sacks',
                                      'team2_int',
                                      'team2_fmbl',
                                      'teams'])

# %%
g16 = get_game_df(pd.read_csv('pbp-2016.csv'))
g15 = get_game_df(pd.read_csv('pbp-2015.csv'))
g14 = get_game_df(pd.read_csv('pbp-2014.csv'))
g13 = get_game_df(pd.read_csv('pbp-2013.csv', error_bad_lines=False))
# Out:
# /Users/home/anaconda/lib/python3.6/site-packages/pandas/core/generic.py:3924: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# b'Skipping line 2331: expected 45 fields, saw 48\nSkipping line 12467: expected 45 fields, saw 46\nSkipping line 15362: expected 45 fields, saw 48\nSkipping line 15376: expected 45 fields, saw 48\n'
# b'Skipping line 36878: expected 45 fields, saw 48\nSkipping line 36885: expected 45 fields, saw 48\nSkipping line 42706: expected 45 fields, saw 46\n'
# /Users/home/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (15,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
d16 = pd.merge(g16, i16)
d15 = pd.merge(g15, i15)
d14 = pd.merge(g14, i14)
d13 = pd.merge(g13, i13)

d16 = d16.apply(align_teams, axis=1)
d15 = d15.apply(align_teams, axis=1)
d14 = d14.apply(align_teams, axis=1)
d13 = d13.apply(align_teams, axis=1)

d16['year'] = 2016
d15['year'] = 2015
d14['year'] = 2014
d13['year'] = 2013

dfs = [d13, d14, d15, d16]

start_dates= {12 : '2012-09-05',
              13 : '2013-09-05',
              14 : '2014-09-04',
              15 : '2015-09-10',
              16 : '2016-09-08',
              17 : '2017-09-08'}

def get_year(d):
    return d.year
    
def get_week_num(d):
    y = int(str(get_year(d))[-2:])
    start = datetime.strptime(start_dates[y], '%Y-%m-%d')
    return ((d - start).days // 7) + 1



for d in dfs:
    fill_win_columns(d)
    d['week'] = d['date'].apply(get_week_num)

# %%
DF = pd.concat(dfs).reset_index().sort_values('date')

# %%
DF.head(10)
# Out:
#     index      gameid       date                team1  \
# 67     67  2013090500 2013-09-05       Denver Broncos
# 70     70  2013090808 2013-09-08   New Orleans Saints
# 68     68  2013090809 2013-09-08  Pittsburgh Steelers
# 79     79  2013090812 2013-09-08       Dallas Cowboys
# 78     78  2013090811 2013-09-08  San Francisco 49ers
# 77     77  2013090805 2013-09-08   Indianapolis Colts
# 76     76  2013090804 2013-09-08    Minnesota Vikings
# 75     75  2013090802 2013-09-08   Cincinnati Bengals
# 74     74  2013090803 2013-09-08       Miami Dolphins
# 73     73  2013090801 2013-09-08     Seattle Seahawks
#
#                                       team1_penalties  team1_passratio  \
# 67  {'DEFENSIVE HOLDING': 1, 'OFFENSIVE PASS INTER...         0.681818
# 70  {'UNNECESSARY ROUGHNESS': 1, 'OFFENSIVE HOLDIN...         0.569231
# 68  {'ILLEGAL BLOCK ABOVE THE WAIST': 1, 'DEFENSIV...         0.702128
# 79         {'FALSE START': 2, 'OFFENSIVE HOLDING': 3}         0.704225
# 78  {'FALSE START': 4, 'ILLEGAL FORMATION': 1, 'DE...         0.520000
# 77  {'LOW BLOCK': 1, 'FACE MASK (15 YARDS)': 1, 'I...         0.510204
# 76  {'ENCROACHMENT': 1, 'ILLEGAL BLOCK ABOVE THE W...         0.591837
# 75  {'ILLEGAL BLOCK ABOVE THE WAIST': 1, 'FACE MAS...         0.625000
# 74  {'FALSE START': 1, 'ILLEGAL FORMATION': 1, 'FA...         0.655738
# 73  {'DEFENSIVE PASS INTERFERENCE': 1, 'ILLEGAL SH...         0.610169
#
#     team1_TD  team1_avgYd  team1_sacks  team1_int  team1_fmbl  \
# 67         7     5.520833            4          2           2
# 70         2     5.168675            3          1           2
# 68         1     3.253968            1          0           1
# 79         2     4.385417            3          3           2
# 78         4     4.930693            2          2           1
# 77         3     4.104478            1          2           0
# 76         4     5.239437            0          1           4
# 75         3     5.800000            0          1           0
# 74         2     3.712644            6          3           1
# 73         1     5.197368            1          0           2
#
#                 team2                                    team2_penalties  \
# 67   Baltimore Ravens  {'OFFENSIVE PASS INTERFERENCE': 1, 'FALSE STAR...
# 70    Atlanta Falcons  {'INTENTIONAL GROUNDING': 1, 'OFFENSIVE HOLDIN...
# 68   Tennessee Titans  {'OFFENSIVE PASS INTERFERENCE': 1, 'ILLEGAL SH...
# 79    New York Giants  {'ILLEGAL SHIFT': 1, 'FALSE START': 1, 'OFFENS...
# 78  Green Bay Packers  {'ILLEGAL USE OF HANDS': 1, 'PERSONAL FOUL': 1...
# 77    Oakland Raiders  {'NEUTRAL ZONE INFRACTION': 2, 'FALSE START': ...
# 76      Detroit Lions  {'OFFENSIVE HOLDING': 3, 'LOW BLOCK': 1, 'DEFE...
# 75      Chicago Bears  {'INELIGIBLE DOWNFIELD PASS': 1, 'DEFENSIVE PA...
# 74   Cleveland Browns  {'DEFENSIVE OFFSIDE': 1, 'ILLEGAL USE OF HANDS...
# 73  Carolina Panthers  {'DISQUALIFICATION': 1, 'UNSPORTSMANLIKE CONDU...
#
#     team2_passratio  team2_TD  team2_avgYd  team2_sacks  team2_int  \
# 67         0.752941         3     3.767857            3          0
# 70         0.735849         2     5.565217            2          1
# 68         0.359375         1     2.927711            5          1
# 79         0.750000         6     7.280000            2          1
# 78         0.637931         4     5.782051            2          0
# 77         0.467742         3     5.584416            4          0
# 76         0.584416         7     5.049505            4          3
# 75         0.540984         3     4.405063            1          2
# 74         0.805556         3     3.847826            4          1
# 73         0.490196         1     4.196721            2          0
#
#     team2_fmbl                                     teams  week  \
# 67           1        (Denver Broncos, Baltimore Ravens)     1
# 70           0     (New Orleans Saints, Atlanta Falcons)     1
# 68           2   (Pittsburgh Steelers, Tennessee Titans)     1
# 79           2         (New York Giants, Dallas Cowboys)     1
# 78           0  (Green Bay Packers, San Francisco 49ers)     1
# 77           0     (Oakland Raiders, Indianapolis Colts)     1
# 76           2        (Detroit Lions, Minnesota Vikings)     1
# 75           2       (Cincinnati Bengals, Chicago Bears)     1
# 74           0        (Cleveland Browns, Miami Dolphins)     1
# 73           2     (Seattle Seahawks, Carolina Panthers)     1
#
#                 team_1  team_1_score               team_2  team_2_score  \
# 67    Baltimore Ravens            27       Denver Broncos            49
# 70     Atlanta Falcons            17   New Orleans Saints            23
# 68    Tennessee Titans            16  Pittsburgh Steelers             9
# 79     New York Giants            31       Dallas Cowboys            36
# 78   Green Bay Packers            28  San Francisco 49ers            34
# 77     Oakland Raiders            17   Indianapolis Colts            21
# 76   Minnesota Vikings            24        Detroit Lions            34
# 75  Cincinnati Bengals            21        Chicago Bears            24
# 74      Miami Dolphins            23     Cleveland Browns            10
# 73    Seattle Seahawks            12    Carolina Panthers             7
#
#     team1_score  team2_score  year  team1_won  team2_won
# 67           49           27  2013          1          0
# 70           23           17  2013          1          0
# 68            9           16  2013          0          1
# 79           36           31  2013          1          0
# 78           34           28  2013          1          0
# 77           21           17  2013          1          0
# 76           24           34  2013          0          1
# 75           21           24  2013          0          1
# 74           23           10  2013          1          0
# 73           12            7  2013          1          0

# %%
s = pd.read_csv('searches.csv', index_col=0)

# %%
t1cols =   ['date',
            'week',
            'year',
            'team1_penalties',
            'team1_passratio',
            'team1_TD',
            'team1_avgYd',
            'team1_sacks',
            'team1_int',
            'team1_fmbl',
            'team1_won',
            'team1_score',]
t2cols =   ['date',
            'week',
            'year',
            'team2_penalties',
            'team2_passratio',
            'team2_TD',
            'team2_avgYd',
            'team2_sacks',
            'team2_int',
            'team2_fmbl',
            'team2_won',
            'team2_score',]



tcols = ['date', 'week', 'year', 'penalties', 'passratio', 'touchdowns', 'avg_yd', 'sacks', 'int', 'fmbl', 'won', 'points']
t1rename = dict(zip(t1cols, tcols))
t2rename = dict(zip(t2cols, tcols))

cols_for_running_avg = ['passratio', 
                        'touchdowns', 
                        'avg_yd', 
                        'sacks','int', 
                        'fmbl', 
                        'won',
                        'points',
                        'total_penalties', 
                        'naughties', 
                        'super_naughties']

def get_team_df(t):
    T1 = DF[t == DF['team1']][t1cols].rename(columns=t1rename)
    T2 = DF[t == DF['team2']][t2cols].rename(columns=t2rename)
    T = pd.concat([T1, T2]).sort_values('date')
    T = pd.merge(T, s[['week', 'year', t]])
    T.rename(columns={t : 'interest'}, inplace=True)
    T['total_penalties'] = T['penalties'].apply(lambda x: sum(x[i] for i in x.elements()))
    T['naughties'] = T['penalties'].apply(sum_of_naughties)
    T['super_naughties'] = T['penalties'].apply(sum_of_super_naughties)
    for c in cols_for_running_avg:
        T[c+'_last'] = T[c].shift(1)
        T[c+'_last_three'] = T[c+'_last'].rolling(3).mean()
        T[c+'_last_five'] = T[c+'_last'].rolling(5).mean()
        T[c+'_total_avg'] = T[c].mean()
    return T
    

teams = list(set(DF.team1.unique()) | set(DF.team2.unique()))
team_dfs = {}
for t in teams:
    team_dfs[t] = get_team_df(t)

# %%
team_dfs['Arizona Cardinals'].head()
# Out:
#         date  week  year                                          penalties  \
# 0 2013-09-15     2  2013  {'RUNNING INTO THE KICKER': 1, 'OFFENSIVE HOLD...
# 1 2013-09-22     3  2013  {'INELIGIBLE DOWNFIELD PASS': 1, 'DEFENSIVE PA...
# 2 2013-09-29     4  2013  {'FALSE START': 3, 'ILLEGAL FORMATION': 2, 'EN...
# 3 2013-10-06     5  2013  {'ILLEGAL FORMATION': 1, 'ROUGHING THE PASSER'...
# 4 2013-10-13     6  2013  {'OFFENSIVE HOLDING': 1, 'FALSE START': 1, 'NE...
#
#    passratio  touchdowns    avg_yd  sacks  int  fmbl  won  points  interest  \
# 0   0.636364           3  4.521739      1    0     1    1      25         1
# 1   0.703704           1  4.449275      4    1     1    0       7         1
# 2   0.694915           1  3.860759      2    2     1    1      13         1
# 3   0.526316           2  3.986667      7    3     1    1      22         2
# 4   0.671875           4  6.400000      2    1     2    0      20         3
#
#    total_penalties  naughties  super_naughties  passratio_last  \
# 0                9          1                0             NaN
# 1                4          2                0        0.636364
# 2               19          3                1        0.703704
# 3                3          1                1        0.694915
# 4                8          3                2        0.526316
#
#    passratio_last_three  passratio_last_five  passratio_total_avg  \
# 0                   NaN                  NaN             0.603154
# 1                   NaN                  NaN             0.603154
# 2                   NaN                  NaN             0.603154
# 3              0.678328                  NaN             0.603154
# 4              0.641645                  NaN             0.603154
#
#    touchdowns_last  touchdowns_last_three  touchdowns_last_five  \
# 0              NaN                    NaN                   NaN
# 1              3.0                    NaN                   NaN
# 2              1.0                    NaN                   NaN
# 3              1.0               1.666667                   NaN
# 4              2.0               1.333333                   NaN
#
#    touchdowns_total_avg  avg_yd_last  avg_yd_last_three  avg_yd_last_five  \
# 0              3.083333          NaN                NaN               NaN
# 1              3.083333     4.521739                NaN               NaN
# 2              3.083333     4.449275                NaN               NaN
# 3              3.083333     3.860759           4.277258               NaN
# 4              3.083333     3.986667           4.098901               NaN
#
#    avg_yd_total_avg  sacks_last  sacks_last_three  sacks_last_five  \
# 0          4.565789         NaN               NaN              NaN
# 1          4.565789         1.0               NaN              NaN
# 2          4.565789         4.0               NaN              NaN
# 3          4.565789         2.0          2.333333              NaN
# 4          4.565789         7.0          4.333333              NaN
#
#    sacks_total_avg  int_last  int_last_three  int_last_five  int_total_avg  \
# 0         2.833333       NaN             NaN            NaN       1.233333
# 1         2.833333       0.0             NaN            NaN       1.233333
# 2         2.833333       1.0             NaN            NaN       1.233333
# 3         2.833333       2.0             1.0            NaN       1.233333
# 4         2.833333       3.0             2.0            NaN       1.233333
#
#    fmbl_last  fmbl_last_three  fmbl_last_five  fmbl_total_avg  won_last  \
# 0        NaN              NaN             NaN             1.3       NaN
# 1        1.0              NaN             NaN             1.3       1.0
# 2        1.0              NaN             NaN             1.3       0.0
# 3        1.0              1.0             NaN             1.3       1.0
# 4        1.0              1.0             NaN             1.3       1.0
#
#    won_last_three  won_last_five  won_total_avg  points_last  \
# 0             NaN            NaN       0.666667          NaN
# 1             NaN            NaN       0.666667         25.0
# 2             NaN            NaN       0.666667          7.0
# 3        0.666667            NaN       0.666667         13.0
# 4        0.666667            NaN       0.666667         22.0
#
#    points_last_three  points_last_five  points_total_avg  \
# 0                NaN               NaN         25.166667
# 1                NaN               NaN         25.166667
# 2                NaN               NaN         25.166667
# 3               15.0               NaN         25.166667
# 4               14.0               NaN         25.166667
#
#    total_penalties_last  total_penalties_last_three  \
# 0                   NaN                         NaN
# 1                   9.0                         NaN
# 2                   4.0                         NaN
# 3                  19.0                   10.666667
# 4                   3.0                    8.666667
#
#    total_penalties_last_five  total_penalties_total_avg  naughties_last  \
# 0                        NaN                  10.516667             NaN
# 1                        NaN                  10.516667             1.0
# 2                        NaN                  10.516667             2.0
# 3                        NaN                  10.516667             3.0
# 4                        NaN                  10.516667             1.0
#
#    naughties_last_three  naughties_last_five  naughties_total_avg  \
# 0                   NaN                  NaN             2.116667
# 1                   NaN                  NaN             2.116667
# 2                   NaN                  NaN             2.116667
# 3                   2.0                  NaN             2.116667
# 4                   2.0                  NaN             2.116667
#
#    super_naughties_last  super_naughties_last_three  \
# 0                   NaN                         NaN
# 1                   0.0                         NaN
# 2                   0.0                         NaN
# 3                   1.0                    0.333333
# 4                   1.0                    0.666667
#
#    super_naughties_last_five  super_naughties_total_avg
# 0                        NaN                   0.683333
# 1                        NaN                   0.683333
# 2                        NaN                   0.683333
# 3                        NaN                   0.683333
# 4                        NaN                   0.683333

# %%
S = pd.concat(team_dfs.values()).dropna()
S.head(10)
# Out:
#          date  week  year                                          penalties  \
# 5  2013-10-13     6  2013  {'DELAY OF GAME': 3, 'INELIGIBLE DOWNFIELD KIC...
# 6  2013-10-27     8  2013  {'OFFENSIVE HOLDING': 1, 'DELAY OF GAME': 2, '...
# 7  2013-11-03     9  2013  {'OFFENSIVE HOLDING': 3, 'DEFENSIVE OFFSIDE': ...
# 8  2013-11-03     9  2013  {'OFFENSIVE HOLDING': 3, 'DEFENSIVE OFFSIDE': ...
# 9  2013-11-10    10  2013  {'OFFENSIVE HOLDING': 4, 'FALSE START': 2, 'IL...
# 10 2013-11-17    11  2013  {'FALSE START': 2, 'UNNECESSARY ROUGHNESS': 1,...
# 11 2013-11-24    12  2013  {'ROUGHING THE PASSER': 1, 'FACE MASK (15 YARD...
# 12 2013-11-28    13  2013  {'NEUTRAL ZONE INFRACTION': 2, 'ROUGHING THE P...
# 13 2013-12-08    14  2013  {'ILLEGAL FORMATION': 1, 'FALSE START': 1, 'OF...
# 14 2013-12-08    14  2013  {'ILLEGAL FORMATION': 1, 'FALSE START': 1, 'OF...
#
#     passratio  touchdowns    avg_yd  sacks  int  fmbl  won  points  interest  \
# 5    0.569231           2  3.720430      3    0     3    0       7         2
# 6    0.345455           3  3.881579      5    3     1    1      21         3
# 7    0.637363           2  5.175439      1    0     0    0      20         1
# 8    0.637363           2  5.175439      1    0     0    0      20         2
# 9    0.509434           2  3.945946      3    1     2    0      20         2
# 10   0.507937           5  3.780220      2    1     3    1      28         3
# 11   0.618182           1  4.916667      2    0     3    0      19         5
# 12   0.607843           4  4.197368      2    0     2    0      24         2
# 13   0.609375           4  4.776471      1    1     1    0      27         1
# 14   0.609375           4  4.776471      1    1     1    0      27         2
#
#     total_penalties  naughties  super_naughties  passratio_last  \
# 5                26          1                0        0.500000
# 6                 8          1                0        0.569231
# 7                20          3                1        0.345455
# 8                20          3                1        0.637363
# 9                24          1                0        0.637363
# 10               24          3                2        0.509434
# 11                6          2                1        0.507937
# 12               25          5                2        0.618182
# 13                5          1                1        0.607843
# 14                5          1                1        0.609375
#
#     passratio_last_three  passratio_last_five  passratio_total_avg  \
# 5               0.576023             0.523908             0.610804
# 6               0.543545             0.544206             0.610804
# 7               0.471562             0.528551             0.610804
# 8               0.517349             0.522690             0.610804
# 9               0.540060             0.537882             0.610804
# 10              0.594720             0.539769             0.610804
# 11              0.551578             0.527510             0.610804
# 12              0.545184             0.582056             0.610804
# 13              0.577987             0.576152             0.610804
# 14              0.611800             0.570554             0.610804
#
#     touchdowns_last  touchdowns_last_three  touchdowns_last_five  \
# 5               3.0               2.666667                   2.4
# 6               2.0               2.333333                   2.2
# 7               3.0               2.666667                   2.6
# 8               2.0               2.333333                   2.4
# 9               2.0               2.333333                   2.4
# 10              2.0               2.000000                   2.2
# 11              5.0               3.000000                   2.8
# 12              1.0               2.666667                   2.4
# 13              4.0               3.333333                   2.8
# 14              4.0               3.000000                   3.2
#
#     touchdowns_total_avg  avg_yd_last  avg_yd_last_three  avg_yd_last_five  \
# 5               2.859155     4.565789           4.646775          4.741985
# 6               2.859155     3.720430           4.141820          4.369188
# 7               2.859155     3.881579           4.055933          4.308467
# 8               2.859155     5.175439           4.259149          4.296496
# 9               2.859155     5.175439           4.744152          4.503735
# 10              2.859155     3.945946           4.765608          4.379766
# 11              2.859155     3.780220           4.300535          4.391724
# 12              2.859155     4.916667           4.214277          4.598742
# 13              2.859155     4.197368           4.298085          4.403128
# 14              2.859155     4.776471           4.630169          4.323334
#
#     avg_yd_total_avg  sacks_last  sacks_last_three  sacks_last_five  \
# 5           4.425904         2.0          1.333333              2.6
# 6           4.425904         3.0          2.000000              2.4
# 7           4.425904         5.0          3.333333              2.4
# 8           4.425904         1.0          3.000000              2.4
# 9           4.425904         1.0          2.333333              2.4
# 10          4.425904         3.0          1.666667              2.6
# 11          4.425904         2.0          2.000000              2.4
# 12          4.425904         2.0          2.333333              1.8
# 13          4.425904         2.0          2.000000              2.0
# 14          4.425904         1.0          1.666667              2.0
#
#     sacks_total_avg  int_last  int_last_three  int_last_five  int_total_avg  \
# 5          2.070423       3.0        1.000000            0.6        0.84507
# 6          2.070423       0.0        1.000000            0.6        0.84507
# 7          2.070423       3.0        2.000000            1.2        0.84507
# 8          2.070423       0.0        1.000000            1.2        0.84507
# 9          2.070423       0.0        1.000000            1.2        0.84507
# 10         2.070423       1.0        0.333333            0.8        0.84507
# 11         2.070423       1.0        0.666667            1.0        0.84507
# 12         2.070423       0.0        0.666667            0.4        0.84507
# 13         2.070423       0.0        0.333333            0.4        0.84507
# 14         2.070423       1.0        0.333333            0.6        0.84507
#
#     fmbl_last  fmbl_last_three  fmbl_last_five  fmbl_total_avg  won_last  \
# 5         2.0         2.333333             1.6        1.295775       1.0
# 6         3.0         2.333333             2.2        1.295775       0.0
# 7         1.0         2.000000             2.2        1.295775       1.0
# 8         0.0         1.333333             1.6        1.295775       0.0
# 9         0.0         0.333333             1.2        1.295775       0.0
# 10        2.0         0.666667             1.2        1.295775       0.0
# 11        3.0         1.666667             1.2        1.295775       1.0
# 12        3.0         2.666667             1.6        1.295775       0.0
# 13        2.0         2.666667             2.0        1.295775       0.0
# 14        1.0         2.000000             2.2        1.295775       0.0
#
#     won_last_three  won_last_five  won_total_avg  points_last  \
# 5         0.333333            0.4       0.422535         27.0
# 6         0.333333            0.4       0.422535          7.0
# 7         0.666667            0.4       0.422535         21.0
# 8         0.333333            0.4       0.422535         20.0
# 9         0.333333            0.4       0.422535         20.0
# 10        0.000000            0.2       0.422535         20.0
# 11        0.333333            0.4       0.422535         28.0
# 12        0.333333            0.2       0.422535         19.0
# 13        0.333333            0.2       0.422535         24.0
# 14        0.000000            0.2       0.422535         27.0
#
#     points_last_three  points_last_five  points_total_avg  \
# 5           20.666667              19.6         22.478873
# 6           16.000000              17.6         22.478873
# 7           18.333333              18.0         22.478873
# 8           16.000000              17.8         22.478873
# 9           20.333333              19.0         22.478873
# 10          20.000000              17.6         22.478873
# 11          22.666667              21.8         22.478873
# 12          22.333333              21.4         22.478873
# 13          23.666667              22.2         22.478873
# 14          23.333333              23.6         22.478873
#
#     total_penalties_last  total_penalties_last_three  \
# 5                   13.0                   12.333333
# 6                   26.0                   16.000000
# 7                    8.0                   15.666667
# 8                   20.0                   18.000000
# 9                   20.0                   16.000000
# 10                  24.0                   21.333333
# 11                  24.0                   22.666667
# 12                   6.0                   18.000000
# 13                  25.0                   18.333333
# 14                   5.0                   12.000000
#
#     total_penalties_last_five  total_penalties_total_avg  naughties_last  \
# 5                        12.8                  16.408451             3.0
# 6                        15.2                  16.408451             1.0
# 7                        14.2                  16.408451             1.0
# 8                        15.2                  16.408451             3.0
# 9                        17.4                  16.408451             3.0
# 10                       19.6                  16.408451             1.0
# 11                       19.2                  16.408451             3.0
# 12                       18.8                  16.408451             2.0
# 13                       19.8                  16.408451             5.0
# 14                       16.8                  16.408451             1.0
#
#     naughties_last_three  naughties_last_five  naughties_total_avg  \
# 5               1.333333                  1.6             2.591549
# 6               1.333333                  1.0             2.591549
# 7               1.666667                  1.2             2.591549
# 8               1.666667                  1.6             2.591549
# 9               2.333333                  2.2             2.591549
# 10              2.333333                  1.8             2.591549
# 11              2.333333                  2.2             2.591549
# 12              2.000000                  2.4             2.591549
# 13              3.333333                  2.8             2.591549
# 14              2.666667                  2.4             2.591549
#
#     super_naughties_last  super_naughties_last_three  \
# 5                    2.0                    0.666667
# 6                    0.0                    0.666667
# 7                    0.0                    0.666667
# 8                    1.0                    0.333333
# 9                    1.0                    0.666667
# 10                   0.0                    0.666667
# 11                   2.0                    1.000000
# 12                   1.0                    1.000000
# 13                   2.0                    1.666667
# 14                   1.0                    1.333333
#
#     super_naughties_last_five  super_naughties_total_avg
# 5                         0.6                   0.647887
# 6                         0.4                   0.647887
# 7                         0.4                   0.647887
# 8                         0.6                   0.647887
# 9                         0.8                   0.647887
# 10                        0.4                   0.647887
# 11                        0.8                   0.647887
# 12                        1.0                   0.647887
# 13                        1.2                   0.647887
# 14                        1.2                   0.647887

# %%
#commented to prevent accidental overwrite
#S.to_csv('final.csv')

# %% [markdown]
# Below is where I started to incorporate the injury data

# %%
start_dates= {12 : '2012-09-05',
              13 : '2013-09-05',
              14 : '2014-09-04',
              15 : '2015-09-10',
              16 : '2016-09-08',
              17 : '2017-09-08'}

def get_year(d):
    try:
        if type(d) == str:
            d = datetime.strptime(d, '%Y-%m-%d')
        return d.year
    except ValueError:
        return None
    
def get_week_num(d):
    try:
        if type(d) == str:
            d = datetime.strptime(d, '%Y-%m-%d')
        y = int(str(get_year(d))[-2:])
        start = datetime.strptime(start_dates[y], '%Y-%m-%d')
        return ((d - start).days // 7) + 1
    except ValueError:
        return None
    
def string_cat(a, b):
    return str(a) + str(b)

df = pd.read_csv('final.csv')

# %%
I = pd.concat([i13, i14, i15, i16])

# %%
inj = pd.read_csv('injuries.csv', index_col=0, header=0)

# %%
labels = [x.replace('\xa0', '') for x in list(inj.head().iloc[0])]
rename_dict = dict(zip([str(i) for i in range(5)], labels))
inj.rename(columns=rename_dict, inplace=True)
inj.drop(0, inplace=True)
inj['i'] = inj['Relinquished'].apply(len)
inj = inj[inj.i > 0][['Date', 'Team']]
inj = inj[inj.Date != '\xa0Date']
inj['Date'] = inj['Date'].apply(to_datetime)
inj = inj[inj.Date > '2012-02-01']
inj['team'] = inj['Team'].apply(get_full_name)
inj['year'] = inj['Date'].apply(get_year)
inj['week'] = inj['Date'].apply(get_week_num)

# %%
def to_datetime(d):
    return datetime.strptime(d, '%Y-%m-%d')

# %%
inj = inj[inj.week > 0]
inj = inj[inj.week < 18]
inj.head()

# %%
I['year'] = I['date'].apply(get_year)

# %%
m1 = pd.merge(I, inj.rename(columns={'team' : 'team_1'}))
m1

# %%
def get_full_name(s):
    n = [t for t in teams if {s.replace(' ','')} <= set(t.split(' '))]
    if n:
        return n[0]
    return np.nan

# %%
type('') == str
