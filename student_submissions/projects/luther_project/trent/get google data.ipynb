# %%
import requests
import numpy as np
import re
from bs4 import BeautifulSoup
import pandas as pd
from collections import defaultdict, Counter
from functools import partial, reduce
from datetime import datetime, date, timedelta
import pickle
import math
path = !pwd
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 100

# %%
def scrub_date(d):
    d = d.split('/')
    d[0].zfill(2)
    d[1].zfill(2)
    d = reduce(string_cat, d)
    return datetime.strptime(d, '%m%d%y')

# %%
teams = ['Houston Texans',
         'Pittsburgh Steelers',
         'Arizona Cardinals',
         'Buffalo Bills',
         'Miami Dolphins',
         'Tampa Bay Buccaneers',
         'San Diego Chargers',
         'Cleveland Browns',
         'New York Giants',
         'Cincinnati Bengals',
         'Denver Broncos',
         'Minnesota Vikings',
         'Carolina Panthers',
         'San Francisco 49ers',
         'Washington Redskins',
         'Philadelphia Eagles',
         'Indianapolis Colts',
         'New Orleans Saints',
         'New York Jets',
         'Detroit Lions',
         'Tennessee Titans',
         'Oakland Raiders',
         'New England Patriots',
         'Dallas Cowboys',
         'Baltimore Ravens',
         'Green Bay Packers',
         'Kansas City Chiefs',
         'Seattle Seahawks',
         'Chicago Bears',
         'Atlanta Falcons',
         'Jacksonville Jaguars',
         'Los Angeles Rams']

# %%
start_dates= {12 : '2012-09-05',
              13 : '2013-09-05',
              14 : '2014-09-04',
              15 : '2015-09-10',
              16 : '2016-09-08',
              17 : '2017-09-08'}

def get_year(d):
    return d.year
    
def get_week_num(d):
    y = int(str(get_year(d))[-2:])
    start = datetime.strptime(start_dates[y], '%Y-%m-%d')
    return ((d - start).days // 7) + 1

df['week'] = df['date'].apply(get_week_num)

# %%
def string_cat(a, b):
    return str(a) + str(b)

# %%
df = pd.read_csv('search_data.csv')

# %%
column_rename_dict = dict((x, x.split(':')[0]) for x in df.columns)
df.rename(columns=column_rename_dict, inplace=True)
df.rename(columns={'Los Angeles Chargers' : 'San Diego Chargers'}, inplace=True)

# %%
df['date'] = df['Week'].apply(scrub_date)
df['week'] = df['date'].apply(get_week_num)
df['year'] = df['date'].apply(get_year)

# %%
df = df[['year', 'week'] + teams]

# %%
df = df[df.year > 2012]
df = df[df.week > 0]
df = df[df.week < 18]

# %%
df.to_csv('searches.csv')

# %%
df.sort_values('year')
# Out:
#      year  week  Houston Texans  Pittsburgh Steelers  Arizona Cardinals  \
# 14   2013     9               4                    1                  1
# 64   2013    17               2                    4                  1
# 63   2013    16               1                    4                  2
# 62   2013    15               1                    4                  1
# 61   2013    14               1                    3                  1
# 59   2013    12               1                    6                  1
# 58   2013    11               2                    4                  1
# 57   2013    10               2                    3                  1
# 56   2013     9               4                    3                  1
# 60   2013    13               3                    2                  1
# 54   2013     7               2                    4                  1
# 53   2013     6               2                    3                  3
# ...
