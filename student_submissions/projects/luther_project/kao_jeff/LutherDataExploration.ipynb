# %%
import pandas as pd

# %%
# read everything from file
players_df = pd.read_csv('player_list.csv', index_col=0)
player_seasons_df = pd.read_csv('player_seasons_list.csv', index_col=0)

# %%
player_seasons_df[player_seasons_df['team_id'] == 'TOT']
# Out:
#         age  ast_per_g  blk_per_g  canonical  drb_per_g  efg_pct  fg2_pct  \
# 2      24.0        0.4        0.3  abdelal01        2.8    0.518    0.519
# 6      26.0        0.2        0.2  abdelal01        1.4    0.511    0.515
# 9      22.0        0.8        NaN  abdulza01        NaN      NaN      NaN
# 20     31.0        0.6        0.2  abdulza01        1.9      NaN      NaN
# 54     25.0        1.6        0.5  abdulta01        3.1    0.426    0.435
# 58     27.0        1.0        0.4  abdulta01        1.8    0.378    0.372
# 69     27.0        2.0        0.4  abdursh01        5.3    0.480    0.482
# 80     26.0        0.5        0.1  abernto01        0.7    0.424    0.431
# 85     28.0        0.2        NaN  abramjo01        NaN      NaN      NaN
# 90     26.0        0.5        0.2  ackeral01        0.6    0.441    0.411
# 99     30.0        0.3        0.3  acresma01        2.3    0.541    0.532
# 104    23.0        0.4        0.4    acyqu01        2.3    0.482    0.492
# ...

# %%
team_seasons_df = pd.read_csv('team_seasons_list.csv')

# %%
team_seasons_df
# Out:
#       Unnamed: 0             canonical   season initials lg_id  \
# 0              0  /teams/ATL/2018.html  2017-18      ATL   NBA
# 1              1  /teams/ATL/2017.html  2016-17      ATL   NBA
# 2              2  /teams/ATL/2016.html  2015-16      ATL   NBA
# 3              3  /teams/ATL/2015.html  2014-15      ATL   NBA
# 4              4  /teams/ATL/2014.html  2013-14      ATL   NBA
# 5              5  /teams/ATL/2013.html  2012-13      ATL   NBA
# 6              6  /teams/ATL/2012.html  2011-12      ATL   NBA
# 7              7  /teams/ATL/2011.html  2010-11      ATL   NBA
# 8              8  /teams/ATL/2010.html  2009-10      ATL   NBA
# 9              9  /teams/ATL/2009.html  2008-09      ATL   NBA
# 10            10  /teams/ATL/2008.html  2007-08      ATL   NBA
# 11            11  /teams/ATL/2007.html  2006-07      ATL   NBA
# 12            12  /teams/ATL/2006.html  2005-06      ATL   NBA
# 13            13  /teams/ATL/2005.html  2004-05      ATL   NBA
# ...

# %%
list1 = sorted(player_seasons_df.team_id.unique())

# %%
list2 = sorted(team_seasons_df.initials.unique())

# %%
# further cleaning of the player's table: 
# if they have 'multiple' teams within the same season, the total (TOT) describes the total for that season
