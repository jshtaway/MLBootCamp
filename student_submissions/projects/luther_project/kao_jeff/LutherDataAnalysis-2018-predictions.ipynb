# %% [markdown]
# ### 2018 Predictions with our best models

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
# To plot matplotlib figures inline on the notebook
# %matplotlib inline

from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.ensemble import RandomForestRegressor

from sklearn.cross_validation import cross_val_score, train_test_split, KFold
from sklearn.grid_search import GridSearchCV
# Out:
# /anaconda/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda/lib/python3.5/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from luther_common import *

# %%
# categories to predict
pred_categories = ['pts_per_g',
         'fg_per_g','fga_per_g',
         'fg3_per_g','fg3a_per_g',
         'ft_per_g','fta_per_g',
         'trb_per_g','blk_per_g',
         'stl_per_g','ast_per_g',
         'tov_per_g'
        ]

# %%
# load our predictive and standardization models
from sklearn.externals import joblib
estimators = dict()
standardizers = dict()

for category in pred_categories:
    estimators[category]=joblib.load('best_linreg_predictor_'+category+'.pkl')
    standardizers[category]=joblib.load('best_linreg_standardizer_'+category+'.pkl')

# %%
# load our data:
X_df = pd.read_csv('LEBRON_data_feng_2018.csv', index_col=0)
pred_df = X_df.copy()

# %%
# best prediction using 'D' mask:
level = 'D'
for category in pred_categories:
    #piggyback off the existing mask function to mask the X and y
    ready_X, _ = mask_data(category, level, X_df, None)
    std_ready_X = standardizers[category].transform(ready_X)
    pred_df[category] = estimators[category].predict(std_ready_X)
# Out:
# /Users/j2kao/Documents/METIS/metis_projects/luther/luther_common.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ready_X.drop(excluded_columns, axis=1, inplace=True)

# %%
pred_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 324 entries, 0 to 323
# Data columns (total 170 columns):
# age_0_ya              float64
# age_1_ya              float64
# age_2_ya              float64
# age_3_ya              float64
# ast_per_g_0_ya        float64
# ast_per_g_1_ya        float64
# ast_per_g_2_ya        float64
# ast_per_g_3_ya        float64
# blk_per_g_0_ya        float64
# blk_per_g_1_ya        float64
# blk_per_g_2_ya        float64
# blk_per_g_3_ya        float64
# canonical             object
# canonical_0_ya        object
# canonical_1_ya        object
# canonical_2_ya        object
# canonical_3_ya        object
# drb_per_g_0_ya        float64
# drb_per_g_1_ya        float64
# drb_per_g_2_ya        float64
# drb_per_g_3_ya        float64
# eff_ratio_0_ya        float64
# eff_ratio_1_ya        float64
# eff_ratio_2_ya        float64
# eff_ratio_3_ya        float64
# eff_raw_0_ya          float64
# eff_raw_1_ya          float64
# eff_raw_2_ya          float64
# eff_raw_3_ya          float64
# fg2_per_g_0_ya        float64
# fg2_per_g_1_ya        float64
# fg2_per_g_2_ya        float64
# fg2_per_g_3_ya        float64
# fg2a_per_g_0_ya       float64
# fg2a_per_g_1_ya       float64
# fg2a_per_g_2_ya       float64
# fg2a_per_g_3_ya       float64
# fg3_per_g_0_ya        float64
# fg3_per_g_1_ya        float64
# fg3_per_g_2_ya        float64
# fg3_per_g_3_ya        float64
# fg3a_per_g_0_ya       float64
# fg3a_per_g_1_ya       float64
# fg3a_per_g_2_ya       float64
# fg3a_per_g_3_ya       float64
# fg_per_g_0_ya         float64
# fg_per_g_1_ya         float64
# fg_per_g_2_ya         float64
# fg_per_g_3_ya         float64
# fga_per_g_0_ya        float64
# fga_per_g_1_ya        float64
# fga_per_g_2_ya        float64
# fga_per_g_3_ya        float64
# ft_per_g_0_ya         float64
# ft_per_g_1_ya         float64
# ft_per_g_2_ya         float64
# ft_per_g_3_ya         float64
# fta_per_g_0_ya        float64
# fta_per_g_1_ya        float64
# fta_per_g_2_ya        float64
# fta_per_g_3_ya        float64
# g_0_ya                int64
# g_1_ya                int64
# g_2_ya                int64
# g_3_ya                int64
# height_inches         float64
# mp_per_g_0_ya         float64
# mp_per_g_1_ya         float64
# mp_per_g_2_ya         float64
# mp_per_g_3_ya         float64
# name_0_ya             object
# name_1_ya             object
# name_2_ya             object
# name_3_ya             object
# orb_per_g_0_ya        float64
# orb_per_g_1_ya        float64
# orb_per_g_2_ya        float64
# orb_per_g_3_ya        float64
# pf_per_g_0_ya         float64
# pf_per_g_1_ya         float64
# pf_per_g_2_ya         float64
# pf_per_g_3_ya         float64
# pos_C_0_ya            float64
# pos_C_1_ya            float64
# pos_C_2_ya            float64
# pos_C_3_ya            float64
# pos_PF_0_ya           float64
# pos_PF_1_ya           float64
# pos_PF_2_ya           float64
# pos_PF_3_ya           float64
# pos_PG_0_ya           float64
# pos_PG_1_ya           float64
# pos_PG_2_ya           float64
# pos_PG_3_ya           float64
# pos_SF_0_ya           float64
# pos_SF_1_ya           float64
# pos_SF_2_ya           float64
# pos_SF_3_ya           float64
# pos_SG_0_ya           float64
# pos_SG_1_ya           float64
# pos_SG_2_ya           float64
# pos_SG_3_ya           float64
# poscat_0_ya           float64
# poscat_1_ya           float64
# poscat_2_ya           float64
# poscat_3_ya           float64
# pts_per_g_0_ya        float64
# pts_per_g_1_ya        float64
# pts_per_g_2_ya        float64
# pts_per_g_3_ya        float64
# season_0_ya           object
# season_1_ya           object
# season_2_ya           object
# season_3_ya           object
# season_year_0_ya      float64
# season_year_1_ya      float64
# season_year_2_ya      float64
# season_year_3_ya      float64
# stl_per_g_0_ya        float64
# stl_per_g_1_ya        float64
# stl_per_g_2_ya        float64
# stl_per_g_3_ya        float64
# team_id_0_ya          object
# team_id_1_ya          object
# team_id_2_ya          object
# team_id_3_ya          object
# team_pace_0_ya        float64
# team_pace_1_ya        float64
# team_pace_2_ya        float64
# team_pace_3_ya        float64
# tov_per_g_0_ya        float64
# tov_per_g_1_ya        float64
# tov_per_g_2_ya        float64
# tov_per_g_3_ya        float64
# trb_per_g_0_ya        float64
# trb_per_g_1_ya        float64
# trb_per_g_2_ya        float64
# trb_per_g_3_ya        float64
# weight                float64
# yrs_in_league_0_ya    float64
# yrs_in_league_1_ya    float64
# yrs_in_league_2_ya    float64
# yrs_in_league_3_ya    float64
# pts_per_g_pred        float64
# fg_per_g_pred         float64
# fga_per_g_pred        float64
# fg3_per_g_pred        float64
# fg3a_per_g_pred       float64
# ft_per_g_pred         float64
# fta_per_g_pred        float64
# trb_per_g_pred        float64
# blk_per_g_pred        float64
# stl_per_g_pred        float64
# ast_per_g_pred        float64
# tov_per_g_pred        float64
# eff_raw_pred          float64
# eff_ratio_pred        float64
# team_pace_pred        float64
# pts_per_g             float64
# fg_per_g              float64
# fga_per_g             float64
# fg3_per_g             float64
# fg3a_per_g            float64
# ft_per_g              float64
# fta_per_g             float64
# trb_per_g             float64
# blk_per_g             float64
# stl_per_g             float64
# ast_per_g             float64
# tov_per_g             float64
# dtypes: float64(149), int64(4), object(17)
# memory usage: 432.8+ KB

# %%
# we need to cut down pred_df so it's usable
exclusion_criteria = ['pos_','_0_ya','_1_ya','_2_ya','_3_ya','eff_raw','_pred']
exclusion_exceptions = [
    'age_0_ya','poscat_0_ya','yrs_in_league_0_ya'
]
excluded_columns = []
for col in pred_df.columns:
    #if fits exclusion criteria but does not MATCH an exception
    if (        any(excrit in col for excrit in exclusion_criteria)
        and not any(exexcp == col for exexcp in exclusion_exceptions)):
        excluded_columns.append(col)
pred_df_save = pred_df.drop(excluded_columns, axis=1)

# %%
pred_df_save.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 324 entries, 0 to 323
# Data columns (total 18 columns):
# age_0_ya              324 non-null float64
# canonical             324 non-null object
# height_inches         324 non-null float64
# poscat_0_ya           324 non-null float64
# weight                324 non-null float64
# yrs_in_league_0_ya    324 non-null float64
# pts_per_g             324 non-null float64
# fg_per_g              324 non-null float64
# fga_per_g             324 non-null float64
# fg3_per_g             324 non-null float64
# fg3a_per_g            324 non-null float64
# ft_per_g              324 non-null float64
# fta_per_g             324 non-null float64
# trb_per_g             324 non-null float64
# blk_per_g             324 non-null float64
# stl_per_g             324 non-null float64
# ast_per_g             324 non-null float64
# tov_per_g             324 non-null float64
# dtypes: float64(17), object(1)
# memory usage: 48.1+ KB

# %%
# read in team rosters so we can get a player name + keys
team_rosters_df = pd.read_csv('team_rosters_list.csv', index_col=0)
# add season_year column
team_rosters_df.rename(columns={'season':'season_year','player_canonical':'canonical','initial':'team_id','player':'name'}, 
                       inplace=True)
team_rosters_keys_df = team_rosters_df[['season_year','team_id','canonical','name']]
team_rosters_keys_df = team_rosters_keys_df[team_rosters_keys_df['season_year'] == 2018].reset_index(drop=True)
team_rosters_keys_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 4 columns):
# season_year    537 non-null int64
# team_id        537 non-null object
# canonical      537 non-null object
# name           537 non-null object
# dtypes: int64(1), object(3)
# memory usage: 16.9+ KB

# %%
final_df = pd.merge(team_rosters_keys_df, 
                     pred_df_save, 
                     how='left', 
                     left_on=['canonical'], 
                     right_on=['canonical'])

# %%
final_df['eff_raw'] = (final_df['pts_per_g'] +\
                            final_df['trb_per_g'] +\
                            final_df['ast_per_g'] +\
                            final_df['stl_per_g'] +\
                            final_df['blk_per_g'] -\
                           ((final_df['fga_per_g'] - final_df['fg_per_g']) +\
                            (final_df['fta_per_g'] - final_df['ft_per_g']) +\
                             final_df['tov_per_g'])) * 72

# %%
final_df.loc[177,:]
# Out:
# season_year                   2018
# team_id                        HOU
# canonical                hardeja01
# name                  James Harden
# age_0_ya                        28
# height_inches                   77
# poscat_0_ya                      1
# weight                         220
# yrs_in_league_0_ya               8
# pts_per_g                  29.4421
# fg_per_g                   8.89449
# fga_per_g                  20.0287
# fg3_per_g                   2.9908
# fg3a_per_g                 8.44136
# ft_per_g                    8.6012
# fta_per_g                   10.281
# trb_per_g                  7.65452
# blk_per_g                 0.551153
# stl_per_g                  1.69029
# ast_per_g                  9.94492
# tov_per_g                  4.91543
# eff_raw                    2271.85
# Name: 177, dtype: object

# %%
final_df.sort_values('pts_per_g',ascending=False)
# Out:
#      season_year team_id  canonical                   name  age_0_ya  \
# 360         2018     OKC  westbru01      Russell Westbrook      29.0
# 177         2018     HOU  hardeja01           James Harden      28.0
# 321         2018     NOP  davisan02          Anthony Davis      24.0
# 322         2018     NOP  couside01       DeMarcus Cousins      27.0
# 89          2018     CLE  thomais02          Isaiah Thomas      28.0
# 165         2018     GSW  duranke01           Kevin Durant      29.0
# 433         2018     POR  lillada01         Damian Lillard      27.0
# 489         2018     TOR  derozde01          DeMar DeRozan      28.0
# 158         2018     GSW  curryst01          Stephen Curry      29.0
# 469         2018     SAS  leonaka01          Kawhi Leonard      26.0
# 96          2018     CLE  jamesle01           LeBron James      33.0
# 19          2018     BOS  irvinky01           Kyrie Irving      25.0
# 309         2018     MIN  butleji01           Jimmy Butler      28.0
# 286         2018     MIL  antetgi01  Giannis Antetokounmpo      23.0
# 306         2018     MIN  wiggian01         Andrew Wiggins      22.0
# 522         2018     WAS   walljo01              John Wall      27.0
# 358         2018     OKC  georgpa01            Paul George      27.0
# 54          2018     CHO  walkeke02           Kemba Walker      27.0
# 26          2018     BOS  haywago01         Gordon Hayward      27.0
# 530         2018     WAS   bealbr01           Bradley Beal      24.0
# 159         2018     GSW  thompkl01          Klay Thompson      27.0
# 434         2018     POR  mccolcj01          C.J. McCollum      26.0
# 497         2018     TOR  lowryky01             Kyle Lowry      31.0
# 225         2018     LAC  griffbl01          Blake Griffin      28.0
# 414         2018     PHO  bledser01           Eric Bledsoe      28.0
# 359         2018     OKC  anthoca01        Carmelo Anthony      33.0
# 287         2018     MIL  parkeja01          Jabari Parker      22.0
# 255         2018     MEM  conlemi01            Mike Conley      30.0
# 233         2018     LAL  lopezbr01            Brook Lopez      29.0
# 91          2018     CLE   loveke01             Kevin Love      29.0
# ..           ...     ...        ...                    ...       ...
# 476         2018     SAS  whitede01          Derrick White       NaN
# 477         2018     SAS   paulbr01           Brandon Paul       NaN
# 481         2018     SAS  perralo01       London Perrantes       NaN
# 483         2018     SAS  brimaam01           Amida Brimah       NaN
# 487         2018     TOR  wrighde01           Delon Wright       NaN
# 488         2018     TOR  powelno01          Norman Powell       NaN
# 490         2018     TOR  poeltja01           Jakob Poeltl       NaN
# 491         2018     TOR  siakapa01          Pascal Siakam       NaN
# 492         2018     TOR  vanvlfr01          Fred VanVleet       NaN
# 493         2018     TOR  anunoog01             OG Anunoby       NaN
# 494         2018     TOR  mckinal01       Alfonzo McKinnie       NaN
# 495         2018     TOR  meekske01          Kennedy Meeks       NaN
# 499         2018     TOR  wiltjky01           Kyle Wiltjer       NaN
# 501         2018     TOR  rautian01           Andy Rautins       NaN
# 506         2018     UTA   exumda01             Dante Exum       NaN
# 508         2018     UTA   netora01              Raul Neto       NaN
# 510         2018     UTA  bolomjo01          Joel Bolomboy       NaN
# 511         2018     UTA  mitchdo01       Donovan Mitchell       NaN
# 512         2018     UTA  bradlto01           Tony Bradley       NaN
# 515         2018     UTA  onealro01           Royce O'Neal       NaN
# 516         2018     UTA   udohek01              Ekpe Udoh       NaN
# 518         2018     UTA  mitrona01        Naz Mitrou-Long       NaN
# 519         2018     UTA  braunta01           Taylor Braun       NaN
# 523         2018     WAS  oubreke01        Kelly Oubre Jr.       NaN
# 524         2018     WAS  mcculch01       Chris McCullough       NaN
# 527         2018     WAS  ochefda01          Daniel Ochefu       NaN
# 528         2018     WAS  satorto01       Tomas Satoransky       NaN
# 531         2018     WAS  mcclesh01            Sheldon Mac       NaN
# 535         2018     WAS  sloando01           Donald Sloan       NaN
# 536         2018     WAS  felixca01          Carrick Felix       NaN
#
#      height_inches  poscat_0_ya  weight  yrs_in_league_0_ya  pts_per_g  \
# 360           75.0          1.0   200.0                 9.0  30.566640
# 177           77.0          1.0   220.0                 8.0  29.442064
# 321           82.0          5.0   253.0                 5.0  27.930258
# 322           83.0          5.0   270.0                 7.0  26.308361
# 89            69.0          1.0   185.0                 6.0  26.254514
# 165           81.0          3.0   240.0                10.0  26.132612
# 433           75.0          1.0   195.0                 5.0  26.059964
# 489           79.0          2.0   221.0                 8.0  25.892538
# 158           75.0          1.0   190.0                 8.0  25.485032
# 469           79.0          3.0   230.0                 6.0  25.275385
# 96            80.0          3.0   250.0                14.0  25.042159
# 19            75.0          1.0   193.0                 6.0  24.205567
# 309           79.0          3.0   220.0                 6.0  23.639572
# 286           83.0          3.0   222.0                 4.0  23.585302
# 306           80.0          3.0   199.0                 3.0  22.800256
# 522           76.0          1.0   195.0                 7.0  22.586063
# 358           81.0          3.0   220.0                 7.0  22.438252
# 54            73.0          1.0   172.0                 6.0  22.054146
# 26            80.0          3.0   226.0                 7.0  21.623285
# 530           77.0          2.0   207.0                 5.0  21.596979
# 159           79.0          2.0   215.0                 6.0  21.365688
# 434           75.0          2.0   190.0                 4.0  20.802992
# 497           72.0          1.0   205.0                11.0  20.754060
# 225           82.0          4.0   251.0                 7.0  20.732068
# 414           73.0          1.0   205.0                 7.0  20.556855
# 359           80.0          3.0   240.0                14.0  20.257021
# 287           80.0          4.0   250.0                 3.0  19.314048
# 255           73.0          1.0   175.0                10.0  19.217930
# 233           84.0          5.0   275.0                 9.0  18.808442
# 91            82.0          4.0   251.0                 9.0  18.768633
# ..             ...          ...     ...                 ...        ...
# 476            NaN          NaN     NaN                 NaN        NaN
# 477            NaN          NaN     NaN                 NaN        NaN
# 481            NaN          NaN     NaN                 NaN        NaN
# 483            NaN          NaN     NaN                 NaN        NaN
# 487            NaN          NaN     NaN                 NaN        NaN
# 488            NaN          NaN     NaN                 NaN        NaN
# 490            NaN          NaN     NaN                 NaN        NaN
# 491            NaN          NaN     NaN                 NaN        NaN
# 492            NaN          NaN     NaN                 NaN        NaN
# 493            NaN          NaN     NaN                 NaN        NaN
# 494            NaN          NaN     NaN                 NaN        NaN
# 495            NaN          NaN     NaN                 NaN        NaN
# 499            NaN          NaN     NaN                 NaN        NaN
# 501            NaN          NaN     NaN                 NaN        NaN
# 506            NaN          NaN     NaN                 NaN        NaN
# 508            NaN          NaN     NaN                 NaN        NaN
# 510            NaN          NaN     NaN                 NaN        NaN
# 511            NaN          NaN     NaN                 NaN        NaN
# 512            NaN          NaN     NaN                 NaN        NaN
# 515            NaN          NaN     NaN                 NaN        NaN
# 516            NaN          NaN     NaN                 NaN        NaN
# 518            NaN          NaN     NaN                 NaN        NaN
# 519            NaN          NaN     NaN                 NaN        NaN
# 523            NaN          NaN     NaN                 NaN        NaN
# 524            NaN          NaN     NaN                 NaN        NaN
# 527            NaN          NaN     NaN                 NaN        NaN
# 528            NaN          NaN     NaN                 NaN        NaN
# 531            NaN          NaN     NaN                 NaN        NaN
# 535            NaN          NaN     NaN                 NaN        NaN
# 536            NaN          NaN     NaN                 NaN        NaN
#
#         ...       fg3_per_g  fg3a_per_g  ft_per_g  fta_per_g  trb_per_g  \
# 360     ...        2.254686    6.617798  7.886749   9.565817   9.738158
# 177     ...        2.990802    8.441357  8.601204  10.281031   7.654519
# 321     ...        0.758123    2.270098  6.389745   8.166826  11.583239
# 322     ...        1.521986    4.435801  6.854976   8.948753  10.983758
# 89      ...        2.822118    7.731268  6.674082   7.587227   3.418943
# 165     ...        2.028051    5.333776  5.496369   6.515223   8.459768
# 433     ...        2.806670    7.576374  5.832765   6.704476   5.131477
# 489     ...        0.766479    2.300612  6.737942   8.014578   5.377931
# 158     ...        3.816289    9.738284  4.313595   4.911051   5.153673
# 469     ...        2.001981    5.357027  5.643051   6.650303   6.816068
# 96      ...        1.568791    4.447946  4.738290   6.779436   8.086377
# 19      ...        2.337944    6.194422  4.113960   4.773212   3.862240
# 309     ...        1.398189    3.867699  6.616178   7.850046   6.413863
# 286     ...        0.859367    2.623869  5.550463   7.292782   9.084121
# 306     ...        1.321282    3.680774  4.948853   6.362491   4.724444
# 522     ...        1.326036    3.929170  4.870835   6.092008   4.832925
# 358     ...        2.369436    6.365793  4.567851   5.283111   6.576911
# 54      ...        2.653349    7.161198  4.091551   4.827115   4.426078
# 26      ...        1.943806    5.218537  4.847298   5.879281   5.769867
# 530     ...        2.586054    6.820830  3.531022   4.251433   3.893306
# 159     ...        3.154895    8.053442  2.600348   3.030480   3.985440
# 434     ...        2.111789    5.482461  3.129823   3.644248   3.832006
# 497     ...        2.766840    7.345192  4.644600   5.657194   4.850710
# 225     ...        0.704214    2.038438  4.489386   5.953912   7.817257
# 414     ...        1.629530    4.682411  5.115680   6.123401   4.863752
# 359     ...        1.830837    5.144074  3.770220   4.534063   5.879969
# 287     ...        1.225938    3.384967  3.223458   4.191765   6.504197
# 255     ...        2.189035    5.821804  4.110214   4.807212   3.663690
# 233     ...        1.382015    3.982372  3.671428   4.636137   6.172158
# 91      ...        2.236248    6.057051  4.005165   4.813705  10.285969
# ..      ...             ...         ...       ...        ...        ...
# 476     ...             NaN         NaN       NaN        NaN        NaN
# 477     ...             NaN         NaN       NaN        NaN        NaN
# 481     ...             NaN         NaN       NaN        NaN        NaN
# 483     ...             NaN         NaN       NaN        NaN        NaN
# 487     ...             NaN         NaN       NaN        NaN        NaN
# 488     ...             NaN         NaN       NaN        NaN        NaN
# 490     ...             NaN         NaN       NaN        NaN        NaN
# 491     ...             NaN         NaN       NaN        NaN        NaN
# 492     ...             NaN         NaN       NaN        NaN        NaN
# 493     ...             NaN         NaN       NaN        NaN        NaN
# 494     ...             NaN         NaN       NaN        NaN        NaN
# 495     ...             NaN         NaN       NaN        NaN        NaN
# 499     ...             NaN         NaN       NaN        NaN        NaN
# 501     ...             NaN         NaN       NaN        NaN        NaN
# 506     ...             NaN         NaN       NaN        NaN        NaN
# 508     ...             NaN         NaN       NaN        NaN        NaN
# 510     ...             NaN         NaN       NaN        NaN        NaN
# 511     ...             NaN         NaN       NaN        NaN        NaN
# 512     ...             NaN         NaN       NaN        NaN        NaN
# 515     ...             NaN         NaN       NaN        NaN        NaN
# 516     ...             NaN         NaN       NaN        NaN        NaN
# 518     ...             NaN         NaN       NaN        NaN        NaN
# 519     ...             NaN         NaN       NaN        NaN        NaN
# 523     ...             NaN         NaN       NaN        NaN        NaN
# 524     ...             NaN         NaN       NaN        NaN        NaN
# 527     ...             NaN         NaN       NaN        NaN        NaN
# 528     ...             NaN         NaN       NaN        NaN        NaN
# 531     ...             NaN         NaN       NaN        NaN        NaN
# 535     ...             NaN         NaN       NaN        NaN        NaN
# 536     ...             NaN         NaN       NaN        NaN        NaN
#
#      blk_per_g  stl_per_g  ast_per_g  tov_per_g      eff_raw
# 360   0.431623   1.875469   9.982305   4.857541  2379.709074
# 177   0.551153   1.690285   9.944917   4.915431  2271.846174
# 321   2.130759   1.422988   2.791606   2.509491  2234.765628
# 322   1.277914   1.490867   4.542337   3.758881  2031.800149
# 89    0.163091   1.097893   6.037119   2.914761  1625.723557
# 165   1.353976   1.093980   5.080867   2.764017  2088.223624
# 433   0.364892   1.081678   6.170659   2.927807  1731.340651
# 489   0.297811   1.165963   4.285260   2.593760  1616.191040
# 158   0.293682   1.849761   6.761861   3.037892  1847.188699
# 469   0.794203   1.870372   4.065692   2.305694  1854.257997
# 96    0.638663   1.329118   7.777971   3.643547  2018.168269
# 19    0.348733   1.335784   5.720268   2.629075  1556.691946
# 309   0.521922   1.748208   5.402457   2.381254  1795.330824
# 286   1.612484   1.496290   5.517477   3.112895  1996.947605
# 306   0.532557   1.114701   2.690175   2.386828  1312.472371
# 522   0.638959   1.869359   9.984190   3.971307  1788.738591
# 358   0.450527   1.528198   3.657150   2.815607  1532.799304
# 54    0.382500   1.350665   5.432165   2.221204  1485.745423
# 26    0.387646   1.181687   3.854475   2.343624  1473.446171
# 530   0.318132   1.182355   3.687184   2.156170  1327.028358
# 159   0.577942   0.935680   2.411307   1.705419  1271.863264
# 434   0.438834   1.076280   3.607558   2.167023  1283.622180
# 497   0.290657   1.596618   6.602210   2.778812  1561.587458
# 225   0.516142   0.941082   4.727299   2.403102  1636.601032
# 414   0.514212   1.554696   6.214663   3.254168  1501.576639
# 359   0.456417   0.854754   2.930557   2.022866  1299.976292
# 287   0.461748   1.153595   3.002134   2.027714  1375.602911
# 255   0.300725   1.315580   6.143805   2.314814  1399.366886
# 233   1.487133   0.669612   2.108770   2.084475  1335.737582
# 91    0.508513   0.923518   2.506733   2.004635  1590.468907
# ..         ...        ...        ...        ...          ...
# 476        NaN        NaN        NaN        NaN          NaN
# 477        NaN        NaN        NaN        NaN          NaN
# 481        NaN        NaN        NaN        NaN          NaN
# 483        NaN        NaN        NaN        NaN          NaN
# 487        NaN        NaN        NaN        NaN          NaN
# 488        NaN        NaN        NaN        NaN          NaN
# 490        NaN        NaN        NaN        NaN          NaN
# 491        NaN        NaN        NaN        NaN          NaN
# 492        NaN        NaN        NaN        NaN          NaN
# 493        NaN        NaN        NaN        NaN          NaN
# 494        NaN        NaN        NaN        NaN          NaN
# 495        NaN        NaN        NaN        NaN          NaN
# 499        NaN        NaN        NaN        NaN          NaN
# 501        NaN        NaN        NaN        NaN          NaN
# 506        NaN        NaN        NaN        NaN          NaN
# 508        NaN        NaN        NaN        NaN          NaN
# 510        NaN        NaN        NaN        NaN          NaN
# 511        NaN        NaN        NaN        NaN          NaN
# 512        NaN        NaN        NaN        NaN          NaN
# 515        NaN        NaN        NaN        NaN          NaN
# 516        NaN        NaN        NaN        NaN          NaN
# 518        NaN        NaN        NaN        NaN          NaN
# 519        NaN        NaN        NaN        NaN          NaN
# 523        NaN        NaN        NaN        NaN          NaN
# 524        NaN        NaN        NaN        NaN          NaN
# 527        NaN        NaN        NaN        NaN          NaN
# 528        NaN        NaN        NaN        NaN          NaN
# 531        NaN        NaN        NaN        NaN          NaN
# 535        NaN        NaN        NaN        NaN          NaN
# 536        NaN        NaN        NaN        NaN          NaN
#
# [537 rows x 22 columns]

# %%
row = final_df[final_df['name'] == 'LeBron James']
row
# Out:
#     season_year team_id  canonical          name  age_0_ya  height_inches  \
# 96         2018     CLE  jamesle01  LeBron James      33.0           80.0
#
#     poscat_0_ya  weight  yrs_in_league_0_ya  pts_per_g     ...       \
# 96          3.0   250.0                14.0  25.042159     ...
#
#     fg3_per_g  fg3a_per_g  ft_per_g  fta_per_g  trb_per_g  blk_per_g  \
# 96   1.568791    4.447946   4.73829   6.779436   8.086377   0.638663
#
#     stl_per_g  ast_per_g  tov_per_g      eff_raw
# 96   1.329118   7.777971   3.643547  2018.168269
#
# [1 rows x 22 columns]

# %%
row.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 96 to 96
# Data columns (total 22 columns):
# season_year           1 non-null int64
# team_id               1 non-null object
# canonical             1 non-null object
# name                  1 non-null object
# age_0_ya              1 non-null float64
# height_inches         1 non-null float64
# poscat_0_ya           1 non-null float64
# weight                1 non-null float64
# yrs_in_league_0_ya    1 non-null float64
# pts_per_g             1 non-null float64
# fg_per_g              1 non-null float64
# fga_per_g             1 non-null float64
# fg3_per_g             1 non-null float64
# fg3a_per_g            1 non-null float64
# ft_per_g              1 non-null float64
# fta_per_g             1 non-null float64
# trb_per_g             1 non-null float64
# blk_per_g             1 non-null float64
# stl_per_g             1 non-null float64
# ast_per_g             1 non-null float64
# tov_per_g             1 non-null float64
# eff_raw               1 non-null float64
# dtypes: float64(18), int64(1), object(3)
# memory usage: 184.0+ bytes

# %%
pd.isnull(row.iloc[0,4])
# Out:
# True

# %%
final_df.to_csv('LEBRON_2018_FINAL_PREDICTIONS.csv')
